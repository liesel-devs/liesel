# %% [markdown]
# # BatchManager exploration
#
# This notebook mirrors the optimizer walkthrough in `test_optim.ipynb`, but uses two observed branches with different observation sizes. It compares a strict `BatchManager` configuration with equal numbers of child batches and an automatic max-alignment configuration with unequal child batch counts.

# %%
import jax
import jax.numpy as jnp
import optax
import tensorflow_probability.substrates.jax.bijectors as tfb
import tensorflow_probability.substrates.jax.distributions as tfd

import liesel.model as lsl
import liesel.optim as opt
from liesel.optim.types import Position

# %% [markdown]
# The two branches below have different observation sizes. A `SplitManager` keeps each full array in its own child split; each child `Batches` object owns one observed variable.

# %%
data_key = jax.random.key(42)
x_key, y_key = jax.random.split(data_key)

xval = 1.5 + 0.7 * jax.random.normal(x_key, (1_200,))
yval = -0.5 + 1.3 * jax.random.normal(y_key, (800,))

data = opt.SplitManager(
    [
        opt.Split(["x"], axis_size=xval.size),
        opt.Split(["y"], axis_size=yval.size),
    ]
).split_position(Position({"x": xval, "y": yval}))

# %% [markdown]
# The strict configuration uses different observation sizes but the same number of full child batches. The automatic max-alignment configuration intentionally uses unequal child batch counts and lets the shorter child sequence sample rows again within a joint epoch.

# %%
def make_strict_batches():
    return opt.BatchManager(
        [
            opt.Batches(["x"], axis_size=xval.size, batch_size=120, shuffle=True),
            opt.Batches(["y"], axis_size=yval.size, batch_size=80, shuffle=True),
        ],
    )


def make_max_batches():
    return opt.BatchManager(
        [
            opt.Batches(["x"], axis_size=xval.size, batch_size=150, shuffle=True),
            opt.Batches(["y"], axis_size=yval.size, batch_size=80, shuffle=True),
        ],
        epoch_size="max",
    )


strict_batches = make_strict_batches()
max_batches = make_max_batches()

# %%
def summarize_batches(manager):
    return {
        "epoch_size": manager.epoch_size,
        "n": manager.axis_size,
        "batch_size": manager.batch_size,
        "batch_sample_scales": manager.batch_sample_scales,
        "n_full_batches": manager.n_full_batches,
        "is_full_data": manager.is_full_data,
    }


summarize_batches(strict_batches), summarize_batches(max_batches)
# Out:
# ({'epoch_size': 'strict',
#   'n': (1200, 800),
#   'batch_size': (120, 80),
#   'batch_sample_scales': (10.0, 10.0),
#   'n_full_batches': 10,
#   'is_full_data': False},
#  {'epoch_size': 'max',
#   'n': (1200, 800),
#   'batch_size': (150, 80),
#   'batch_sample_scales': (8.0, 10.0),
#   'n_full_batches': 10,
#   'is_full_data': False})

# %% [markdown]
# `start_epoch()` prepares child-specific permutations and the joint sequence of child batch rows. Creating a fresh manager before starting an epoch keeps the notebook cells independent when they are re-run out of order.

# %%
strict_epoch = make_strict_batches().start_epoch(jax.random.key(1))
max_epoch = make_max_batches().start_epoch(jax.random.key(1))

(
    [child.batch_indices.tolist() for child in strict_epoch.batches],
    [child.batch_indices.tolist() for child in max_epoch.batches],
)
# Out:
# ([[[213,
#     764,
#     660,
#     162,
#     413,
#     602,
#     191,
#     561,
#     965,
#     493,
#     164,
#     1135,
#     825,
#     847,
#     528,
#     666,
#     33,
#     269,
#     1106,
#     411,
#     667,
#     827,
#     479,
#     918,
#     366,
#     347,
#     477,
#     1185,
#     563,
#     811,
#     832,
#     755,
#     504,
#     102,
#     26,
#     105,
#     814,
#     177,
#     913,
#     368,
#     815,
#     143,
#     836,
#     737,
#     1149,
#     952,
#     204,
#     193,
#     268,
#     462,
#     596,
#     2,
#     250,
#     739,
#     586,
#     260,
#     431,
#     5,
#     990,
#     9,
#     14,
#     689,
#     864,
#     173,
#     615,
#     47,
#     983,
#     749,
#     195,
#     765,
#     119,
#     67,
#     131,
#     239,
#     940,
#     227,
#     1060,
#     800,
#     748,
#     236,
#     657,
#     769,
#     432,
#     873,
#     476,
#     71,
#     767,
#     953,
#     1199,
#     926,
#     78,
#     230,
#     1196,
#     207,
#     673,
#     376,
#     155,
#     889,
#     1133,
#     279,
#     552,
#     91,
#     574,
#     130,
#     797,
#     569,
#     1162,
#     353,
#     6,
#     706,
#     202,
#     502,
#     1029,
#     226,
#     1076,
#     306,
#     388,
#     841,
#     240,
#     1063],
#    [893,
#     535,
#     276,
#     969,
#     1171,
#     325,
#     120,
#     86,
#     1157,
#     776,
#     496,
#     319,
#     714,
#     1179,
#     363,
#     539,
#     898,
#     61,
#     231,
#     679,
#     959,
#     1048,
#     43,
#     318,
#     556,
#     564,
#     1145,
#     424,
#     611,
#     571,
#     286,
#     820,
#     335,
#     66,
#     947,
#     872,
#     185,
#     946,
#     1093,
#     533,
#     149,
#     719,
#     1167,
#     1030,
#     850,
#     763,
#     1094,
#     274,
#     685,
#     900,
#     329,
#     669,
#     557,
#     194,
#     521,
#     792,
#     324,
#     980,
#     554,
#     583,
#     50,
#     931,
#     483,
#     1191,
#     172,
#     1034,
#     371,
#     263,
#     187,
#     73,
#     37,
#     796,
#     590,
#     894,
#     942,
#     482,
#     160,
#     516,
#     414,
#     974,
#     439,
#     1144,
#     928,
#     1054,
#     478,
#     664,
#     466,
#     722,
#     10,
#     843,
#     761,
#     824,
#     303,
#     522,
#     192,
#     981,
#     283,
#     1169,
#     448,
#     808,
#     419,
#     1189,
#     752,
#     15,
#     711,
#     812,
#     440,
#     293,
#     865,
#     485,
#     381,
#     1025,
#     117,
#     127,
#     320,
#     861,
#     954,
#     1114,
#     1176,
#     1197],
#    [72,
#     819,
#     395,
#     627,
#     876,
#     412,
#     693,
#     622,
#     735,
#     1091,
#     677,
#     908,
#     1129,
#     471,
#     1122,
#     282,
#     1026,
#     152,
#     1155,
#     1087,
#     948,
#     888,
#     22,
#     1041,
#     182,
#     830,
#     853,
#     1039,
#     1086,
#     1166,
#     302,
#     632,
#     1193,
#     798,
#     45,
#     360,
#     382,
#     680,
#     123,
#     584,
#     1043,
#     189,
#     1023,
#     490,
#     745,
#     153,
#     1184,
#     1164,
#     1065,
#     212,
#     351,
#     708,
#     82,
#     7,
#     452,
#     1180,
#     895,
#     840,
#     782,
#     716,
#     899,
#     261,
#     831,
#     1004,
#     778,
#     316,
#     753,
#     591,
#     80,
#     124,
#     1013,
#     237,
#     807,
#     248,
#     988,
#     924,
#     1107,
#     498,
#     60,
#     1055,
#     998,
#     1084,
#     199,
#     1121,
#     1,
#     206,
#     106,
#     786,
#     217,
#     793,
#     1103,
#     265,
#     542,
#     618,
#     491,
#     108,
#     523,
#     494,
#     1178,
#     573,
#     922,
#     34,
#     158,
#     509,
#     932,
#     350,
#     300,
#     1059,
#     870,
#     1187,
#     1092,
#     624,
#     434,
#     257,
#     1182,
#     857,
#     399,
#     208,
#     1174,
#     538],
#    [972,
#     781,
#     373,
#     866,
#     16,
#     32,
#     1047,
#     1181,
#     570,
#     1015,
#     842,
#     599,
#     871,
#     489,
#     417,
#     547,
#     114,
#     362,
#     845,
#     203,
#     1046,
#     576,
#     1066,
#     1040,
#     386,
#     292,
#     135,
#     731,
#     42,
#     54,
#     636,
#     1109,
#     994,
#     1101,
#     145,
#     639,
#     775,
#     112,
#     146,
#     474,
#     846,
#     1156,
#     134,
#     1049,
#     1110,
#     259,
#     672,
#     416,
#     751,
#     858,
#     587,
#     653,
#     513,
#     1006,
#     49,
#     828,
#     728,
#     97,
#     372,
#     454,
#     115,
#     437,
#     321,
#     621,
#     789,
#     559,
#     1111,
#     1037,
#     692,
#     83,
#     623,
#     391,
#     1075,
#     958,
#     256,
#     1192,
#     892,
#     936,
#     361,
#     85,
#     560,
#     392,
#     470,
#     184,
#     1132,
#     724,
#     943,
#     795,
#     169,
#     558,
#     671,
#     246,
#     24,
#     243,
#     315,
#     168,
#     1082,
#     1134,
#     979,
#     348,
#     255,
#     467,
#     422,
#     179,
#     148,
#     461,
#     374,
#     510,
#     527,
#     548,
#     634,
#     1152,
#     304,
#     1024,
#     52,
#     713,
#     278,
#     1128,
#     605,
#     896],
#    [609,
#     346,
#     642,
#     701,
#     1126,
#     174,
#     646,
#     976,
#     633,
#     519,
#     140,
#     665,
#     1077,
#     472,
#     294,
#     891,
#     920,
#     330,
#     390,
#     3,
#     704,
#     681,
#     906,
#     678,
#     1072,
#     175,
#     553,
#     56,
#     65,
#     822,
#     113,
#     84,
#     938,
#     415,
#     754,
#     326,
#     1044,
#     389,
#     387,
#     779,
#     982,
#     144,
#     698,
#     986,
#     222,
#     1173,
#     715,
#     235,
#     966,
#     762,
#     725,
#     446,
#     585,
#     921,
#     28,
#     238,
#     487,
#     834,
#     610,
#     465,
#     955,
#     460,
#     421,
#     1127,
#     443,
#     12,
#     1158,
#     619,
#     867,
#     442,
#     612,
#     1008,
#     1186,
#     297,
#     418,
#     933,
#     923,
#     662,
#     425,
#     1108,
#     107,
#     1124,
#     420,
#     992,
#     882,
#     883,
#     656,
#     122,
#     799,
#     912,
#     803,
#     1056,
#     400,
#     281,
#     1009,
#     333,
#     447,
#     266,
#     772,
#     862,
#     1073,
#     445,
#     322,
#     600,
#     1120,
#     851,
#     1002,
#     458,
#     393,
#     505,
#     1067,
#     438,
#     1027,
#     4,
#     334,
#     154,
#     603,
#     1096,
#     802,
#     736],
#    [582,
#     228,
#     23,
#     233,
#     264,
#     456,
#     869,
#     1010,
#     598,
#     190,
#     690,
#     902,
#     249,
#     604,
#     455,
#     676,
#     810,
#     405,
#     252,
#     357,
#     1161,
#     784,
#     280,
#     818,
#     718,
#     345,
#     138,
#     317,
#     430,
#     511,
#     961,
#     125,
#     702,
#     1140,
#     205,
#     468,
#     340,
#     919,
#     262,
#     1154,
#     607,
#     1061,
#     978,
#     1021,
#     142,
#     58,
#     497,
#     241,
#     566,
#     267,
#     551,
#     963,
#     1016,
#     848,
#     79,
#     0,
#     879,
#     855,
#     379,
#     29,
#     126,
#     299,
#     1165,
#     1022,
#     90,
#     777,
#     77,
#     31,
#     970,
#     572,
#     1064,
#     717,
#     903,
#     592,
#     401,
#     1052,
#     1045,
#     1198,
#     277,
#     550,
#     688,
#     328,
#     296,
#     180,
#     183,
#     1035,
#     35,
#     410,
#     284,
#     1118,
#     774,
#     518,
#     517,
#     973,
#     137,
#     298,
#     507,
#     884,
#     595,
#     575,
#     760,
#     291,
#     849,
#     74,
#     307,
#     730,
#     530,
#     750,
#     70,
#     396,
#     905,
#     196,
#     308,
#     429,
#     36,
#     694,
#     773,
#     806,
#     652,
#     1070],
#    [910,
#     1038,
#     526,
#     51,
#     644,
#     1019,
#     380,
#     55,
#     428,
#     868,
#     1168,
#     110,
#     385,
#     354,
#     121,
#     1143,
#     1151,
#     95,
#     758,
#     944,
#     780,
#     628,
#     1147,
#     176,
#     1115,
#     691,
#     637,
#     404,
#     514,
#     641,
#     579,
#     794,
#     1083,
#     663,
#     1001,
#     1194,
#     64,
#     805,
#     787,
#     1012,
#     150,
#     904,
#     495,
#     935,
#     365,
#     1183,
#     197,
#     984,
#     939,
#     1142,
#     744,
#     109,
#     46,
#     901,
#     1113,
#     1005,
#     1036,
#     911,
#     41,
#     747,
#     480,
#     524,
#     314,
#     1011,
#     835,
#     1139,
#     295,
#     1068,
#     136,
#     378,
#     655,
#     1105,
#     544,
#     1175,
#     369,
#     188,
#     1100,
#     111,
#     790,
#     640,
#     349,
#     1138,
#     99,
#     225,
#     512,
#     629,
#     648,
#     1071,
#     608,
#     178,
#     129,
#     1112,
#     729,
#     995,
#     877,
#     1148,
#     1028,
#     336,
#     69,
#     81,
#     914,
#     838,
#     536,
#     270,
#     1058,
#     813,
#     977,
#     606,
#     486,
#     1117,
#     1159,
#     103,
#     968,
#     161,
#     500,
#     232,
#     310,
#     342,
#     166,
#     927],
#    [76,
#     821,
#     1003,
#     555,
#     234,
#     703,
#     991,
#     649,
#     929,
#     309,
#     738,
#     159,
#     463,
#     272,
#     39,
#     1078,
#     712,
#     823,
#     220,
#     475,
#     139,
#     817,
#     1089,
#     985,
#     444,
#     1007,
#     647,
#     996,
#     1079,
#     251,
#     484,
#     403,
#     469,
#     1153,
#     506,
#     670,
#     181,
#     1141,
#     394,
#     1031,
#     201,
#     508,
#     273,
#     723,
#     594,
#     289,
#     839,
#     886,
#     338,
#     1033,
#     75,
#     101,
#     1116,
#     989,
#     258,
#     383,
#     38,
#     651,
#     816,
#     216,
#     699,
#     856,
#     1088,
#     1098,
#     11,
#     626,
#     540,
#     1057,
#     741,
#     734,
#     631,
#     682,
#     537,
#     620,
#     783,
#     1069,
#     427,
#     147,
#     885,
#     397,
#     356,
#     305,
#     549,
#     951,
#     331,
#     593,
#     934,
#     13,
#     733,
#     435,
#     859,
#     696,
#     917,
#     746,
#     643,
#     650,
#     630,
#     128,
#     541,
#     473,
#     878,
#     743,
#     407,
#     464,
#     529,
#     451,
#     658,
#     809,
#     118,
#     223,
#     200,
#     355,
#     1125,
#     742,
#     377,
#     515,
#     116,
#     937,
#     290,
#     675],
#    [791,
#     930,
#     343,
#     720,
#     875,
#     520,
#     327,
#     141,
#     98,
#     997,
#     1160,
#     880,
#     344,
#     375,
#     211,
#     975,
#     402,
#     364,
#     907,
#     601,
#     367,
#     863,
#     332,
#     426,
#     244,
#     245,
#     1123,
#     1095,
#     580,
#     48,
#     488,
#     531,
#     1080,
#     1074,
#     697,
#     638,
#     668,
#     617,
#     726,
#     501,
#     63,
#     897,
#     1050,
#     20,
#     625,
#     826,
#     577,
#     1163,
#     285,
#     964,
#     171,
#     589,
#     993,
#     253,
#     1130,
#     684,
#     59,
#     341,
#     654,
#     453,
#     8,
#     709,
#     1062,
#     215,
#     1032,
#     1090,
#     532,
#     1085,
#     481,
#     1177,
#     829,
#     94,
#     209,
#     1042,
#     1051,
#     909,
#     406,
#     960,
#     1000,
#     962,
#     25,
#     337,
#     44,
#     801,
#     785,
#     352,
#     87,
#     854,
#     1119,
#     170,
#     578,
#     613,
#     441,
#     881,
#     1188,
#     683,
#     503,
#     1136,
#     1104,
#     104,
#     359,
#     925,
#     833,
#     588,
#     565,
#     1172,
#     887,
#     165,
#     198,
#     132,
#     370,
#     525,
#     874,
#     218,
#     568,
#     705,
#     674,
#     224,
#     971,
#     457],
#    [1131,
#     987,
#     62,
#     957,
#     967,
#     1014,
#     312,
#     581,
#     1017,
#     645,
#     358,
#     68,
#     770,
#     1195,
#     27,
#     100,
#     732,
#     700,
#     19,
#     852,
#     275,
#     1190,
#     635,
#     408,
#     449,
#     756,
#     687,
#     254,
#     18,
#     459,
#     186,
#     950,
#     1081,
#     221,
#     727,
#     686,
#     740,
#     323,
#     92,
#     1018,
#     1150,
#     271,
#     167,
#     219,
#     88,
#     562,
#     695,
#     1102,
#     659,
#     941,
#     1170,
#     242,
#     597,
#     163,
#     837,
#     614,
#     53,
#     546,
#     759,
#     499,
#     313,
#     287,
#     89,
#     409,
#     616,
#     1099,
#     384,
#     151,
#     1137,
#     210,
#     436,
#     229,
#     721,
#     1020,
#     768,
#     93,
#     214,
#     30,
#     423,
#     956,
#     766,
#     433,
#     1146,
#     96,
#     21,
#     788,
#     398,
#     844,
#     707,
#     543,
#     450,
#     57,
#     156,
#     247,
#     804,
#     999,
#     545,
#     757,
#     492,
#     288,
#     133,
#     40,
#     301,
#     916,
#     157,
#     17,
#     915,
#     710,
#     1053,
#     1097,
#     945,
#     311,
#     339,
#     567,
#     890,
#     771,
#     661,
#     860,
#     534,
#     949]],
#   [[505,
#     13,
#     788,
#     451,
#     157,
#     60,
#     12,
#     340,
#     795,
#     604,
#     297,
#     333,
#     300,
#     171,
#     556,
#     321,
#     748,
#     750,
#     481,
#     444,
#     700,
#     282,
#     702,
#     152,
#     235,
#     371,
#     740,
#     517,
#     346,
#     25,
#     366,
#     88,
#     131,
#     402,
#     793,
#     123,
#     483,
#     545,
#     68,
#     186,
#     758,
#     690,
#     320,
#     586,
#     37,
#     108,
#     9,
#     341,
#     646,
#     466,
#     379,
#     404,
#     209,
#     236,
#     118,
#     343,
#     79,
#     44,
#     531,
#     190,
#     714,
#     34,
#     694,
#     182,
#     319,
#     276,
#     323,
#     504,
#     473,
#     582,
#     357,
#     232,
#     185,
#     301,
#     335,
#     315,
#     591,
#     456,
#     47,
#     374],
#    [698,
#     147,
#     181,
#     799,
#     397,
#     314,
#     546,
#     247,
#     151,
#     294,
#     244,
#     302,
#     479,
#     109,
#     693,
#     625,
#     360,
#     446,
#     318,
#     252,
#     433,
#     362,
#     373,
#     7,
#     200,
#     503,
#     191,
#     299,
#     600,
#     141,
#     169,
#     701,
#     98,
#     681,
#     639,
#     595,
#     20,
#     445,
#     255,
#     501,
#     553,
#     63,
#     437,
#     1,
#     426,
#     197,
#     624,
#     135,
#     749,
#     418,
#     572,
#     163,
#     154,
#     691,
#     59,
#     168,
#     608,
#     784,
#     529,
#     683,
#     568,
#     669,
#     308,
#     718,
#     589,
#     783,
#     226,
#     115,
#     392,
#     729,
#     617,
#     176,
#     31,
#     569,
#     298,
#     3,
#     125,
#     615,
#     237,
#     470],
#    [765,
#     69,
#     530,
#     57,
#     620,
#     21,
#     84,
#     331,
#     344,
#     264,
#     400,
#     428,
#     779,
#     196,
#     334,
#     259,
#     471,
#     66,
#     178,
#     39,
#     140,
#     40,
#     655,
#     541,
#     622,
#     132,
#     723,
#     490,
#     482,
#     679,
#     708,
#     789,
#     381,
#     522,
#     245,
#     609,
#     145,
#     528,
#     290,
#     215,
#     573,
#     219,
#     717,
#     716,
#     90,
#     291,
#     390,
#     557,
#     735,
#     680,
#     274,
#     207,
#     422,
#     195,
#     329,
#     415,
#     94,
#     770,
#     486,
#     202,
#     780,
#     636,
#     695,
#     751,
#     686,
#     443,
#     107,
#     499,
#     307,
#     16,
#     597,
#     644,
#     485,
#     685,
#     385,
#     742,
#     387,
#     164,
#     454,
#     638],
#    [489,
#     77,
#     787,
#     435,
#     210,
#     74,
#     753,
#     22,
#     26,
#     610,
#     263,
#     89,
#     429,
#     268,
#     239,
#     734,
#     648,
#     223,
#     146,
#     100,
#     15,
#     208,
#     143,
#     511,
#     257,
#     567,
#     43,
#     405,
#     175,
#     581,
#     81,
#     18,
#     563,
#     460,
#     342,
#     478,
#     688,
#     174,
#     420,
#     122,
#     467,
#     670,
#     464,
#     376,
#     29,
#     192,
#     542,
#     629,
#     148,
#     436,
#     548,
#     349,
#     386,
#     133,
#     662,
#     540,
#     240,
#     552,
#     286,
#     227,
#     710,
#     348,
#     521,
#     165,
#     177,
#     551,
#     327,
#     419,
#     311,
#     593,
#     287,
#     206,
#     283,
#     576,
#     32,
#     354,
#     220,
#     712,
#     417,
#     743],
#    [547,
#     70,
#     754,
#     258,
#     288,
#     794,
#     36,
#     64,
#     367,
#     440,
#     527,
#     453,
#     324,
#     330,
#     351,
#     78,
#     642,
#     306,
#     325,
#     75,
#     526,
#     111,
#     142,
#     577,
#     313,
#     475,
#     114,
#     689,
#     515,
#     492,
#     676,
#     726,
#     356,
#     53,
#     480,
#     684,
#     173,
#     459,
#     378,
#     0,
#     534,
#     523,
#     635,
#     279,
#     778,
#     137,
#     45,
#     251,
#     305,
#     41,
#     350,
#     537,
#     500,
#     455,
#     369,
#     465,
#     193,
#     663,
#     5,
#     427,
#     113,
#     463,
#     774,
#     23,
#     555,
#     755,
#     8,
#     580,
#     58,
#     382,
#     687,
#     611,
#     380,
#     399,
#     704,
#     285,
#     673,
#     28,
#     727,
#     71],
#    [570,
#     603,
#     658,
#     389,
#     560,
#     762,
#     254,
#     488,
#     99,
#     719,
#     269,
#     120,
#     73,
#     103,
#     442,
#     715,
#     493,
#     509,
#     80,
#     11,
#     205,
#     550,
#     498,
#     222,
#     347,
#     634,
#     30,
#     363,
#     549,
#     278,
#     414,
#     86,
#     139,
#     183,
#     91,
#     671,
#     652,
#     82,
#     262,
#     46,
#     409,
#     469,
#     510,
#     119,
#     623,
#     284,
#     231,
#     637,
#     431,
#     316,
#     322,
#     326,
#     159,
#     72,
#     674,
#     491,
#     613,
#     353,
#     160,
#     138,
#     339,
#     506,
#     150,
#     612,
#     116,
#     665,
#     97,
#     393,
#     134,
#     798,
#     127,
#     166,
#     212,
#     241,
#     93,
#     317,
#     230,
#     457,
#     14,
#     618],
#    [144,
#     158,
#     584,
#     310,
#     292,
#     630,
#     204,
#     769,
#     270,
#     395,
#     413,
#     361,
#     737,
#     711,
#     273,
#     124,
#     539,
#     199,
#     535,
#     95,
#     432,
#     564,
#     4,
#     401,
#     592,
#     633,
#     720,
#     649,
#     606,
#     731,
#     738,
#     434,
#     741,
#     725,
#     83,
#     225,
#     672,
#     643,
#     713,
#     265,
#     358,
#     42,
#     370,
#     744,
#     448,
#     167,
#     518,
#     566,
#     218,
#     359,
#     632,
#     180,
#     621,
#     559,
#     786,
#     761,
#     249,
#     641,
#     777,
#     697,
#     117,
#     229,
#     514,
#     155,
#     468,
#     507,
#     398,
#     194,
#     267,
#     261,
#     657,
#     281,
#     62,
#     38,
#     782,
#     412,
#     458,
#     682,
#     384,
#     705],
#    [544,
#     364,
#     773,
#     706,
#     525,
#     785,
#     519,
#     607,
#     411,
#     92,
#     383,
#     722,
#     295,
#     732,
#     391,
#     484,
#     184,
#     628,
#     312,
#     619,
#     271,
#     248,
#     101,
#     162,
#     739,
#     213,
#     752,
#     508,
#     575,
#     67,
#     211,
#     260,
#     675,
#     170,
#     85,
#     52,
#     388,
#     19,
#     372,
#     757,
#     76,
#     410,
#     707,
#     656,
#     441,
#     33,
#     538,
#     424,
#     562,
#     561,
#     699,
#     476,
#     650,
#     406,
#     709,
#     654,
#     332,
#     588,
#     791,
#     736,
#     96,
#     598,
#     664,
#     214,
#     516,
#     614,
#     24,
#     54,
#     790,
#     692,
#     256,
#     677,
#     243,
#     759,
#     666,
#     277,
#     512,
#     394,
#     61,
#     703],
#    [275,
#     337,
#     416,
#     760,
#     497,
#     121,
#     796,
#     55,
#     474,
#     198,
#     242,
#     355,
#     403,
#     645,
#     189,
#     56,
#     293,
#     439,
#     668,
#     328,
#     583,
#     532,
#     365,
#     602,
#     430,
#     640,
#     423,
#     49,
#     747,
#     156,
#     724,
#     130,
#     2,
#     221,
#     187,
#     730,
#     345,
#     304,
#     733,
#     472,
#     599,
#     763,
#     246,
#     48,
#     309,
#     375,
#     578,
#     27,
#     228,
#     533,
#     792,
#     776,
#     136,
#     746,
#     775,
#     450,
#     571,
#     756,
#     766,
#     447,
#     653,
#     781,
#     513,
#     659,
#     487,
#     266,
#     303,
#     543,
#     129,
#     179,
#     627,
#     772,
#     631,
#     233,
#     651,
#     234,
#     601,
#     494,
#     661,
#     153],
#    [203,
#     771,
#     35,
#     289,
#     352,
#     396,
#     408,
#     425,
#     106,
#     496,
#     17,
#     368,
#     110,
#     217,
#     149,
#     558,
#     536,
#     65,
#     626,
#     253,
#     280,
#     51,
#     112,
#     520,
#     678,
#     767,
#     524,
#     728,
#     105,
#     616,
#     721,
#     250,
#     585,
#     338,
#     128,
#     449,
#     477,
#     565,
#     667,
#     421,
#     50,
#     660,
#     102,
#     587,
#     605,
#     594,
#     272,
#     596,
#     554,
#     188,
#     336,
#     238,
#     296,
#     6,
#     126,
#     161,
#     224,
#     502,
#     377,
#     495,
#     216,
#     797,
#     87,
#     104,
#     461,
#     201,
#     10,
#     590,
#     745,
#     696,
#     462,
#     764,
#     452,
#     647,
#     438,
#     574,
#     172,
#     768,
#     579,
#     407]]],
#  [[[213,
#     764,
#     660,
#     162,
#     413,
#     602,
#     191,
#     561,
#     965,
#     493,
#     164,
#     1135,
#     825,
#     847,
#     528,
#     666,
#     33,
#     269,
#     1106,
#     411,
#     667,
#     827,
#     479,
#     918,
#     366,
#     347,
#     477,
#     1185,
#     563,
#     811,
#     832,
#     755,
#     504,
#     102,
#     26,
#     105,
#     814,
#     177,
#     913,
#     368,
#     815,
#     143,
#     836,
#     737,
#     1149,
#     952,
#     204,
#     193,
#     268,
#     462,
#     596,
#     2,
#     250,
#     739,
#     586,
#     260,
#     431,
#     5,
#     990,
#     9,
#     14,
#     689,
#     864,
#     173,
#     615,
#     47,
#     983,
#     749,
#     195,
#     765,
#     119,
#     67,
#     131,
#     239,
#     940,
#     227,
#     1060,
#     800,
#     748,
#     236,
#     657,
#     769,
#     432,
#     873,
#     476,
#     71,
#     767,
#     953,
#     1199,
#     926,
#     78,
#     230,
#     1196,
#     207,
#     673,
#     376,
#     155,
#     889,
#     1133,
#     279,
#     552,
#     91,
#     574,
#     130,
#     797,
#     569,
#     1162,
#     353,
#     6,
#     706,
#     202,
#     502,
#     1029,
#     226,
#     1076,
#     306,
#     388,
#     841,
#     240,
#     1063,
#     893,
#     535,
#     276,
#     969,
#     1171,
#     325,
#     120,
#     86,
#     1157,
#     776,
#     496,
#     319,
#     714,
#     1179,
#     363,
#     539,
#     898,
#     61,
#     231,
#     679,
#     959,
#     1048,
#     43,
#     318,
#     556,
#     564,
#     1145,
#     424,
#     611,
#     571],
#    [286,
#     820,
#     335,
#     66,
#     947,
#     872,
#     185,
#     946,
#     1093,
#     533,
#     149,
#     719,
#     1167,
#     1030,
#     850,
#     763,
#     1094,
#     274,
#     685,
#     900,
#     329,
#     669,
#     557,
#     194,
#     521,
#     792,
#     324,
#     980,
#     554,
#     583,
#     50,
#     931,
#     483,
#     1191,
#     172,
#     1034,
#     371,
#     263,
#     187,
#     73,
#     37,
#     796,
#     590,
#     894,
#     942,
#     482,
#     160,
#     516,
#     414,
#     974,
#     439,
#     1144,
#     928,
#     1054,
#     478,
#     664,
#     466,
#     722,
#     10,
#     843,
#     761,
#     824,
#     303,
#     522,
#     192,
#     981,
#     283,
#     1169,
#     448,
#     808,
#     419,
#     1189,
#     752,
#     15,
#     711,
#     812,
#     440,
#     293,
#     865,
#     485,
#     381,
#     1025,
#     117,
#     127,
#     320,
#     861,
#     954,
#     1114,
#     1176,
#     1197,
#     72,
#     819,
#     395,
#     627,
#     876,
#     412,
#     693,
#     622,
#     735,
#     1091,
#     677,
#     908,
#     1129,
#     471,
#     1122,
#     282,
#     1026,
#     152,
#     1155,
#     1087,
#     948,
#     888,
#     22,
#     1041,
#     182,
#     830,
#     853,
#     1039,
#     1086,
#     1166,
#     302,
#     632,
#     1193,
#     798,
#     45,
#     360,
#     382,
#     680,
#     123,
#     584,
#     1043,
#     189,
#     1023,
#     490,
#     745,
#     153,
#     1184,
#     1164,
#     1065,
#     212,
#     351,
#     708,
#     82,
#     7,
#     452,
#     1180,
#     895,
#     840,
#     782,
#     716],
#    [899,
#     261,
#     831,
#     1004,
#     778,
#     316,
#     753,
#     591,
#     80,
#     124,
#     1013,
#     237,
#     807,
#     248,
#     988,
#     924,
#     1107,
#     498,
#     60,
#     1055,
#     998,
#     1084,
#     199,
#     1121,
#     1,
#     206,
#     106,
#     786,
#     217,
#     793,
#     1103,
#     265,
#     542,
#     618,
#     491,
#     108,
#     523,
#     494,
#     1178,
#     573,
#     922,
#     34,
#     158,
#     509,
#     932,
#     350,
#     300,
#     1059,
#     870,
#     1187,
#     1092,
#     624,
#     434,
#     257,
#     1182,
#     857,
#     399,
#     208,
#     1174,
#     538,
#     972,
#     781,
#     373,
#     866,
#     16,
#     32,
#     1047,
#     1181,
#     570,
#     1015,
#     842,
#     599,
#     871,
#     489,
#     417,
#     547,
#     114,
#     362,
#     845,
#     203,
#     1046,
#     576,
#     1066,
#     1040,
#     386,
#     292,
#     135,
#     731,
#     42,
#     54,
#     636,
#     1109,
#     994,
#     1101,
#     145,
#     639,
#     775,
#     112,
#     146,
#     474,
#     846,
#     1156,
#     134,
#     1049,
#     1110,
#     259,
#     672,
#     416,
#     751,
#     858,
#     587,
#     653,
#     513,
#     1006,
#     49,
#     828,
#     728,
#     97,
#     372,
#     454,
#     115,
#     437,
#     321,
#     621,
#     789,
#     559,
#     1111,
#     1037,
#     692,
#     83,
#     623,
#     391,
#     1075,
#     958,
#     256,
#     1192,
#     892,
#     936,
#     361,
#     85,
#     560,
#     392,
#     470,
#     184,
#     1132,
#     724,
#     943,
#     795,
#     169,
#     558],
#    [671,
#     246,
#     24,
#     243,
#     315,
#     168,
#     1082,
#     1134,
#     979,
#     348,
#     255,
#     467,
#     422,
#     179,
#     148,
#     461,
#     374,
#     510,
#     527,
#     548,
#     634,
#     1152,
#     304,
#     1024,
#     52,
#     713,
#     278,
#     1128,
#     605,
#     896,
#     609,
#     346,
#     642,
#     701,
#     1126,
#     174,
#     646,
#     976,
#     633,
#     519,
#     140,
#     665,
#     1077,
#     472,
#     294,
#     891,
#     920,
#     330,
#     390,
#     3,
#     704,
#     681,
#     906,
#     678,
#     1072,
#     175,
#     553,
#     56,
#     65,
#     822,
#     113,
#     84,
#     938,
#     415,
#     754,
#     326,
#     1044,
#     389,
#     387,
#     779,
#     982,
#     144,
#     698,
#     986,
#     222,
#     1173,
#     715,
#     235,
#     966,
#     762,
#     725,
#     446,
#     585,
#     921,
#     28,
#     238,
#     487,
#     834,
#     610,
#     465,
#     955,
#     460,
#     421,
#     1127,
#     443,
#     12,
#     1158,
#     619,
#     867,
#     442,
#     612,
#     1008,
#     1186,
#     297,
#     418,
#     933,
#     923,
#     662,
#     425,
#     1108,
#     107,
#     1124,
#     420,
#     992,
#     882,
#     883,
#     656,
#     122,
#     799,
#     912,
#     803,
#     1056,
#     400,
#     281,
#     1009,
#     333,
#     447,
#     266,
#     772,
#     862,
#     1073,
#     445,
#     322,
#     600,
#     1120,
#     851,
#     1002,
#     458,
#     393,
#     505,
#     1067,
#     438,
#     1027,
#     4,
#     334,
#     154,
#     603,
#     1096,
#     802,
#     736],
#    [582,
#     228,
#     23,
#     233,
#     264,
#     456,
#     869,
#     1010,
#     598,
#     190,
#     690,
#     902,
#     249,
#     604,
#     455,
#     676,
#     810,
#     405,
#     252,
#     357,
#     1161,
#     784,
#     280,
#     818,
#     718,
#     345,
#     138,
#     317,
#     430,
#     511,
#     961,
#     125,
#     702,
#     1140,
#     205,
#     468,
#     340,
#     919,
#     262,
#     1154,
#     607,
#     1061,
#     978,
#     1021,
#     142,
#     58,
#     497,
#     241,
#     566,
#     267,
#     551,
#     963,
#     1016,
#     848,
#     79,
#     0,
#     879,
#     855,
#     379,
#     29,
#     126,
#     299,
#     1165,
#     1022,
#     90,
#     777,
#     77,
#     31,
#     970,
#     572,
#     1064,
#     717,
#     903,
#     592,
#     401,
#     1052,
#     1045,
#     1198,
#     277,
#     550,
#     688,
#     328,
#     296,
#     180,
#     183,
#     1035,
#     35,
#     410,
#     284,
#     1118,
#     774,
#     518,
#     517,
#     973,
#     137,
#     298,
#     507,
#     884,
#     595,
#     575,
#     760,
#     291,
#     849,
#     74,
#     307,
#     730,
#     530,
#     750,
#     70,
#     396,
#     905,
#     196,
#     308,
#     429,
#     36,
#     694,
#     773,
#     806,
#     652,
#     1070,
#     910,
#     1038,
#     526,
#     51,
#     644,
#     1019,
#     380,
#     55,
#     428,
#     868,
#     1168,
#     110,
#     385,
#     354,
#     121,
#     1143,
#     1151,
#     95,
#     758,
#     944,
#     780,
#     628,
#     1147,
#     176,
#     1115,
#     691,
#     637,
#     404,
#     514,
#     641],
#    [579,
#     794,
#     1083,
#     663,
#     1001,
#     1194,
#     64,
#     805,
#     787,
#     1012,
#     150,
#     904,
#     495,
#     935,
#     365,
#     1183,
#     197,
#     984,
#     939,
#     1142,
#     744,
#     109,
#     46,
#     901,
#     1113,
#     1005,
#     1036,
#     911,
#     41,
#     747,
#     480,
#     524,
#     314,
#     1011,
#     835,
#     1139,
#     295,
#     1068,
#     136,
#     378,
#     655,
#     1105,
#     544,
#     1175,
#     369,
#     188,
#     1100,
#     111,
#     790,
#     640,
#     349,
#     1138,
#     99,
#     225,
#     512,
#     629,
#     648,
#     1071,
#     608,
#     178,
#     129,
#     1112,
#     729,
#     995,
#     877,
#     1148,
#     1028,
#     336,
#     69,
#     81,
#     914,
#     838,
#     536,
#     270,
#     1058,
#     813,
#     977,
#     606,
#     486,
#     1117,
#     1159,
#     103,
#     968,
#     161,
#     500,
#     232,
#     310,
#     342,
#     166,
#     927,
#     76,
#     821,
#     1003,
#     555,
#     234,
#     703,
#     991,
#     649,
#     929,
#     309,
#     738,
#     159,
#     463,
#     272,
#     39,
#     1078,
#     712,
#     823,
#     220,
#     475,
#     139,
#     817,
#     1089,
#     985,
#     444,
#     1007,
#     647,
#     996,
#     1079,
#     251,
#     484,
#     403,
#     469,
#     1153,
#     506,
#     670,
#     181,
#     1141,
#     394,
#     1031,
#     201,
#     508,
#     273,
#     723,
#     594,
#     289,
#     839,
#     886,
#     338,
#     1033,
#     75,
#     101,
#     1116,
#     989,
#     258,
#     383,
#     38,
#     651,
#     816,
#     216],
#    [699,
#     856,
#     1088,
#     1098,
#     11,
#     626,
#     540,
#     1057,
#     741,
#     734,
#     631,
#     682,
#     537,
#     620,
#     783,
#     1069,
#     427,
#     147,
#     885,
#     397,
#     356,
#     305,
#     549,
#     951,
#     331,
#     593,
#     934,
#     13,
#     733,
#     435,
#     859,
#     696,
#     917,
#     746,
#     643,
#     650,
#     630,
#     128,
#     541,
#     473,
#     878,
#     743,
#     407,
#     464,
#     529,
#     451,
#     658,
#     809,
#     118,
#     223,
#     200,
#     355,
#     1125,
#     742,
#     377,
#     515,
#     116,
#     937,
#     290,
#     675,
#     791,
#     930,
#     343,
#     720,
#     875,
#     520,
#     327,
#     141,
#     98,
#     997,
#     1160,
#     880,
#     344,
#     375,
#     211,
#     975,
#     402,
#     364,
#     907,
#     601,
#     367,
#     863,
#     332,
#     426,
#     244,
#     245,
#     1123,
#     1095,
#     580,
#     48,
#     488,
#     531,
#     1080,
#     1074,
#     697,
#     638,
#     668,
#     617,
#     726,
#     501,
#     63,
#     897,
#     1050,
#     20,
#     625,
#     826,
#     577,
#     1163,
#     285,
#     964,
#     171,
#     589,
#     993,
#     253,
#     1130,
#     684,
#     59,
#     341,
#     654,
#     453,
#     8,
#     709,
#     1062,
#     215,
#     1032,
#     1090,
#     532,
#     1085,
#     481,
#     1177,
#     829,
#     94,
#     209,
#     1042,
#     1051,
#     909,
#     406,
#     960,
#     1000,
#     962,
#     25,
#     337,
#     44,
#     801,
#     785,
#     352,
#     87,
#     854,
#     1119,
#     170],
#    [578,
#     613,
#     441,
#     881,
#     1188,
#     683,
#     503,
#     1136,
#     1104,
#     104,
#     359,
#     925,
#     833,
#     588,
#     565,
#     1172,
#     887,
#     165,
#     198,
#     132,
#     370,
#     525,
#     874,
#     218,
#     568,
#     705,
#     674,
#     224,
#     971,
#     457,
#     1131,
#     987,
#     62,
#     957,
#     967,
#     1014,
#     312,
#     581,
#     1017,
#     645,
#     358,
#     68,
#     770,
#     1195,
#     27,
#     100,
#     732,
#     700,
#     19,
#     852,
#     275,
#     1190,
#     635,
#     408,
#     449,
#     756,
#     687,
#     254,
#     18,
#     459,
#     186,
#     950,
#     1081,
#     221,
#     727,
#     686,
#     740,
#     323,
#     92,
#     1018,
#     1150,
#     271,
#     167,
#     219,
#     88,
#     562,
#     695,
#     1102,
#     659,
#     941,
#     1170,
#     242,
#     597,
#     163,
#     837,
#     614,
#     53,
#     546,
#     759,
#     499,
#     313,
#     287,
#     89,
#     409,
#     616,
#     1099,
#     384,
#     151,
#     1137,
#     210,
#     436,
#     229,
#     721,
#     1020,
#     768,
#     93,
#     214,
#     30,
#     423,
#     956,
#     766,
#     433,
#     1146,
#     96,
#     21,
#     788,
#     398,
#     844,
#     707,
#     543,
#     450,
#     57,
#     156,
#     247,
#     804,
#     999,
#     545,
#     757,
#     492,
#     288,
#     133,
#     40,
#     301,
#     916,
#     157,
#     17,
#     915,
#     710,
#     1053,
#     1097,
#     945,
#     311,
#     339,
#     567,
#     890,
#     771,
#     661,
#     860,
#     534,
#     949],
#    [836,
#     1147,
#     780,
#     975,
#     1138,
#     675,
#     640,
#     84,
#     710,
#     655,
#     599,
#     250,
#     294,
#     187,
#     109,
#     625,
#     494,
#     143,
#     199,
#     730,
#     1153,
#     753,
#     1101,
#     125,
#     544,
#     887,
#     635,
#     124,
#     934,
#     280,
#     300,
#     70,
#     919,
#     401,
#     586,
#     871,
#     278,
#     505,
#     41,
#     688,
#     409,
#     1005,
#     502,
#     598,
#     234,
#     233,
#     795,
#     886,
#     788,
#     529,
#     992,
#     1047,
#     766,
#     1117,
#     577,
#     510,
#     848,
#     10,
#     8,
#     1192,
#     981,
#     1037,
#     807,
#     1110,
#     568,
#     1026,
#     508,
#     462,
#     699,
#     743,
#     1075,
#     1019,
#     939,
#     1015,
#     833,
#     1196,
#     931,
#     422,
#     1099,
#     485,
#     552,
#     399,
#     1150,
#     341,
#     832,
#     956,
#     961,
#     259,
#     538,
#     219,
#     206,
#     859,
#     147,
#     447,
#     913,
#     433,
#     461,
#     285,
#     667,
#     938,
#     56,
#     1167,
#     758,
#     915,
#     248,
#     500,
#     636,
#     933,
#     1178,
#     714,
#     476,
#     279,
#     800,
#     258,
#     572,
#     684,
#     290,
#     679,
#     192,
#     131,
#     532,
#     591,
#     79,
#     151,
#     116,
#     888,
#     615,
#     1081,
#     541,
#     909,
#     520,
#     815,
#     200,
#     155,
#     322,
#     996,
#     954,
#     1014,
#     25,
#     1035,
#     619,
#     369,
#     311,
#     895,
#     1009,
#     1048,
#     930,
#     142,
#     841,
#     872],
#    [148,
#     940,
#     721,
#     948,
#     67,
#     360,
#     22,
#     477,
#     482,
#     486,
#     849,
#     734,
#     495,
#     958,
#     1123,
#     395,
#     66,
#     1163,
#     471,
#     493,
#     986,
#     602,
#     523,
#     1194,
#     331,
#     1082,
#     496,
#     11,
#     862,
#     313,
#     42,
#     504,
#     97,
#     58,
#     720,
#     302,
#     412,
#     418,
#     230,
#     460,
#     81,
#     17,
#     480,
#     988,
#     319,
#     201,
#     220,
#     12,
#     839,
#     781,
#     470,
#     918,
#     1050,
#     613,
#     273,
#     490,
#     846,
#     805,
#     386,
#     359,
#     98,
#     835,
#     1152,
#     1130,
#     1171,
#     1053,
#     650,
#     335,
#     1183,
#     632,
#     160,
#     411,
#     711,
#     6,
#     1103,
#     799,
#     685,
#     1184,
#     609,
#     588,
#     404,
#     812,
#     770,
#     283,
#     676,
#     778,
#     130,
#     207,
#     446,
#     169,
#     1086,
#     791,
#     733,
#     776,
#     345,
#     865,
#     348,
#     530,
#     584,
#     191,
#     31,
#     205,
#     253,
#     226,
#     247,
#     269,
#     574,
#     90,
#     524,
#     1023,
#     54,
#     340,
#     453,
#     712,
#     1134,
#     165,
#     113,
#     1141,
#     582,
#     291,
#     1094,
#     120,
#     357,
#     325,
#     891,
#     212,
#     426,
#     1059,
#     1128,
#     851,
#     1063,
#     276,
#     383,
#     126,
#     1034,
#     282,
#     558,
#     1011,
#     656,
#     481,
#     717,
#     1088,
#     174,
#     397,
#     587,
#     1177,
#     910,
#     52,
#     785,
#     38]],
#   [[505,
#     13,
#     788,
#     451,
#     157,
#     60,
#     12,
#     340,
#     795,
#     604,
#     297,
#     333,
#     300,
#     171,
#     556,
#     321,
#     748,
#     750,
#     481,
#     444,
#     700,
#     282,
#     702,
#     152,
#     235,
#     371,
#     740,
#     517,
#     346,
#     25,
#     366,
#     88,
#     131,
#     402,
#     793,
#     123,
#     483,
#     545,
#     68,
#     186,
#     758,
#     690,
#     320,
#     586,
#     37,
#     108,
#     9,
#     341,
#     646,
#     466,
#     379,
#     404,
#     209,
#     236,
#     118,
#     343,
#     79,
#     44,
#     531,
#     190,
#     714,
#     34,
#     694,
#     182,
#     319,
#     276,
#     323,
#     504,
#     473,
#     582,
#     357,
#     232,
#     185,
#     301,
#     335,
#     315,
#     591,
#     456,
#     47,
#     374],
#    [698,
#     147,
#     181,
#     799,
#     397,
#     314,
#     546,
#     247,
#     151,
#     294,
#     244,
#     302,
#     479,
#     109,
#     693,
#     625,
#     360,
#     446,
#     318,
#     252,
#     433,
#     362,
#     373,
#     7,
#     200,
#     503,
#     191,
#     299,
#     600,
#     141,
#     169,
#     701,
#     98,
#     681,
#     639,
#     595,
#     20,
#     445,
#     255,
#     501,
#     553,
#     63,
#     437,
#     1,
#     426,
#     197,
#     624,
#     135,
#     749,
#     418,
#     572,
#     163,
#     154,
#     691,
#     59,
#     168,
#     608,
#     784,
#     529,
#     683,
#     568,
#     669,
#     308,
#     718,
#     589,
#     783,
#     226,
#     115,
#     392,
#     729,
#     617,
#     176,
#     31,
#     569,
#     298,
#     3,
#     125,
#     615,
#     237,
#     470],
#    [765,
#     69,
#     530,
#     57,
#     620,
#     21,
#     84,
#     331,
#     344,
#     264,
#     400,
#     428,
#     779,
#     196,
#     334,
#     259,
#     471,
#     66,
#     178,
#     39,
#     140,
#     40,
#     655,
#     541,
#     622,
#     132,
#     723,
#     490,
#     482,
#     679,
#     708,
#     789,
#     381,
#     522,
#     245,
#     609,
#     145,
#     528,
#     290,
#     215,
#     573,
#     219,
#     717,
#     716,
#     90,
#     291,
#     390,
#     557,
#     735,
#     680,
#     274,
#     207,
#     422,
#     195,
#     329,
#     415,
#     94,
#     770,
#     486,
#     202,
#     780,
#     636,
#     695,
#     751,
#     686,
#     443,
#     107,
#     499,
#     307,
#     16,
#     597,
#     644,
#     485,
#     685,
#     385,
#     742,
#     387,
#     164,
#     454,
#     638],
#    [489,
#     77,
#     787,
#     435,
#     210,
#     74,
#     753,
#     22,
#     26,
#     610,
#     263,
#     89,
#     429,
#     268,
#     239,
#     734,
#     648,
#     223,
#     146,
#     100,
#     15,
#     208,
#     143,
#     511,
#     257,
#     567,
#     43,
#     405,
#     175,
#     581,
#     81,
#     18,
#     563,
#     460,
#     342,
#     478,
#     688,
#     174,
#     420,
#     122,
#     467,
#     670,
#     464,
#     376,
#     29,
#     192,
#     542,
#     629,
#     148,
#     436,
#     548,
#     349,
#     386,
#     133,
#     662,
#     540,
#     240,
#     552,
#     286,
#     227,
#     710,
#     348,
#     521,
#     165,
#     177,
#     551,
#     327,
#     419,
#     311,
#     593,
#     287,
#     206,
#     283,
#     576,
#     32,
#     354,
#     220,
#     712,
#     417,
#     743],
#    [547,
#     70,
#     754,
#     258,
#     288,
#     794,
#     36,
#     64,
#     367,
#     440,
#     527,
#     453,
#     324,
#     330,
#     351,
#     78,
#     642,
#     306,
#     325,
#     75,
#     526,
#     111,
#     142,
#     577,
#     313,
#     475,
#     114,
#     689,
#     515,
#     492,
#     676,
#     726,
#     356,
#     53,
#     480,
#     684,
#     173,
#     459,
#     378,
#     0,
#     534,
#     523,
#     635,
#     279,
#     778,
#     137,
#     45,
#     251,
#     305,
#     41,
#     350,
#     537,
#     500,
#     455,
#     369,
#     465,
#     193,
#     663,
#     5,
#     427,
#     113,
#     463,
#     774,
#     23,
#     555,
#     755,
#     8,
#     580,
#     58,
#     382,
#     687,
#     611,
#     380,
#     399,
#     704,
#     285,
#     673,
#     28,
#     727,
#     71],
#    [570,
#     603,
#     658,
#     389,
#     560,
#     762,
#     254,
#     488,
#     99,
#     719,
#     269,
#     120,
#     73,
#     103,
#     442,
#     715,
#     493,
#     509,
#     80,
#     11,
#     205,
#     550,
#     498,
#     222,
#     347,
#     634,
#     30,
#     363,
#     549,
#     278,
#     414,
#     86,
#     139,
#     183,
#     91,
#     671,
#     652,
#     82,
#     262,
#     46,
#     409,
#     469,
#     510,
#     119,
#     623,
#     284,
#     231,
#     637,
#     431,
#     316,
#     322,
#     326,
#     159,
#     72,
#     674,
#     491,
#     613,
#     353,
#     160,
#     138,
#     339,
#     506,
#     150,
#     612,
#     116,
#     665,
#     97,
#     393,
#     134,
#     798,
#     127,
#     166,
#     212,
#     241,
#     93,
#     317,
#     230,
#     457,
#     14,
#     618],
#    [144,
#     158,
#     584,
#     310,
#     292,
#     630,
#     204,
#     769,
#     270,
#     395,
#     413,
#     361,
#     737,
#     711,
#     273,
#     124,
#     539,
#     199,
#     535,
#     95,
#     432,
#     564,
#     4,
#     401,
#     592,
#     633,
#     720,
#     649,
#     606,
#     731,
#     738,
#     434,
#     741,
#     725,
#     83,
#     225,
#     672,
#     643,
#     713,
#     265,
#     358,
#     42,
#     370,
#     744,
#     448,
#     167,
#     518,
#     566,
#     218,
#     359,
#     632,
#     180,
#     621,
#     559,
#     786,
#     761,
#     249,
#     641,
#     777,
#     697,
#     117,
#     229,
#     514,
#     155,
#     468,
#     507,
#     398,
#     194,
#     267,
#     261,
#     657,
#     281,
#     62,
#     38,
#     782,
#     412,
#     458,
#     682,
#     384,
#     705],
#    [544,
#     364,
#     773,
#     706,
#     525,
#     785,
#     519,
#     607,
#     411,
#     92,
#     383,
#     722,
#     295,
#     732,
#     391,
#     484,
#     184,
#     628,
#     312,
#     619,
#     271,
#     248,
#     101,
#     162,
#     739,
#     213,
#     752,
#     508,
#     575,
#     67,
#     211,
#     260,
#     675,
#     170,
#     85,
#     52,
#     388,
#     19,
#     372,
#     757,
#     76,
#     410,
#     707,
#     656,
#     441,
#     33,
#     538,
#     424,
#     562,
#     561,
#     699,
#     476,
#     650,
#     406,
#     709,
#     654,
#     332,
#     588,
#     791,
#     736,
#     96,
#     598,
#     664,
#     214,
#     516,
#     614,
#     24,
#     54,
#     790,
#     692,
#     256,
#     677,
#     243,
#     759,
#     666,
#     277,
#     512,
#     394,
#     61,
#     703],
#    [275,
#     337,
#     416,
#     760,
#     497,
#     121,
#     796,
#     55,
#     474,
#     198,
#     242,
#     355,
#     403,
#     645,
#     189,
#     56,
#     293,
#     439,
#     668,
#     328,
#     583,
#     532,
#     365,
#     602,
#     430,
#     640,
#     423,
#     49,
#     747,
#     156,
#     724,
#     130,
#     2,
#     221,
#     187,
#     730,
#     345,
#     304,
#     733,
#     472,
#     599,
#     763,
#     246,
#     48,
#     309,
#     375,
#     578,
#     27,
#     228,
#     533,
#     792,
#     776,
#     136,
#     746,
#     775,
#     450,
#     571,
#     756,
#     766,
#     447,
#     653,
#     781,
#     513,
#     659,
#     487,
#     266,
#     303,
#     543,
#     129,
#     179,
#     627,
#     772,
#     631,
#     233,
#     651,
#     234,
#     601,
#     494,
#     661,
#     153],
#    [203,
#     771,
#     35,
#     289,
#     352,
#     396,
#     408,
#     425,
#     106,
#     496,
#     17,
#     368,
#     110,
#     217,
#     149,
#     558,
#     536,
#     65,
#     626,
#     253,
#     280,
#     51,
#     112,
#     520,
#     678,
#     767,
#     524,
#     728,
#     105,
#     616,
#     721,
#     250,
#     585,
#     338,
#     128,
#     449,
#     477,
#     565,
#     667,
#     421,
#     50,
#     660,
#     102,
#     587,
#     605,
#     594,
#     272,
#     596,
#     554,
#     188,
#     336,
#     238,
#     296,
#     6,
#     126,
#     161,
#     224,
#     502,
#     377,
#     495,
#     216,
#     797,
#     87,
#     104,
#     461,
#     201,
#     10,
#     590,
#     745,
#     696,
#     462,
#     764,
#     452,
#     647,
#     438,
#     574,
#     172,
#     768,
#     579,
#     407]]])

# %%
def batch_shapes(manager, batch_index=0):
    batch = manager.get_batched_position(data.train, batch_index)
    return {name: value.shape for name, value in batch.items()}


batch_shapes(strict_epoch), batch_shapes(max_epoch)
# Out:
# ({'x': (120,), 'y': (80,)}, {'x': (150,), 'y': (80,)})

# %% [markdown]
# Scalar likelihood scaling is still available when all child batch shares match. With unequal shares, use `scaled_log_lik()` so each branch receives its own scaling factor.

# %%
strict_batches.batch_sample_scale
# Out:
# 10.0

# %%
try:
    max_batches.batch_sample_scale  # noqa: B018
except ValueError as error:
    print(error)
# Out:
# BatchManager.batch_sample_scale is only available when all contained Batches objects have the same sample-size ratio. Use per-branch scaling via BatchManager.scaled_log_lik() instead.

# %% [markdown]
# The model has two independent observed branches. The initial model is built from one joint mini-batch because the observed variables receive their batched values during optimization.

# %%
def build_model(initial_batch):
    m_x = lsl.Var.new_param(0.0, name="m_x")
    s_x = lsl.Var.new_param(1.0, name="s_x")
    s_x.transform(tfb.Exp())

    m_y = lsl.Var.new_param(0.0, name="m_y")
    s_y = lsl.Var.new_param(1.0, name="s_y")
    s_y.transform(tfb.Exp())

    x = lsl.Var.new_obs(
        initial_batch["x"],
        distribution=lsl.Dist(tfd.Normal, loc=m_x, scale=s_x),
        name="x",
    )
    y = lsl.Var.new_obs(
        initial_batch["y"],
        distribution=lsl.Dist(tfd.Normal, loc=m_y, scale=s_y),
        name="y",
    )

    return lsl.Model([x, y])

# %%
manager = make_max_batches().start_epoch(jax.random.key(2))
initial_batch = manager.get_batched_position(data.train, 0)
p = build_model(initial_batch)
state = p.update_state(initial_batch, p.state)

manual_scaled_log_lik = (
    manager.batches[0].batch_sample_scale * state["x_log_prob"].value.sum()
    + manager.batches[1].batch_sample_scale * state["y_log_prob"].value.sum()
)

(
    manager.scaled_log_lik(p, state),
    manual_scaled_log_lik,
    jnp.allclose(
        manager.scaled_log_lik(p, state),
        manual_scaled_log_lik,
    ),
)
# Out:
# (Array(-4235.293, dtype=float32),
#  Array(-4235.293, dtype=float32),
#  Array(True, dtype=bool))

# %% [markdown]
# The helper below builds a fresh model, loss, optimizer, and engine for each batch configuration.

# %%
def build_engine(batch_manager, seed=42, learning_rate=1e-2):
    batch_manager = batch_manager.start_epoch(jax.random.key(seed))
    initial_batch = batch_manager.get_batched_position(data.train, 0)
    p = build_model(initial_batch)

    loss = opt.NegLogProbLoss(
        model=p,
        split=data,
        validation_strategy="log_lik",
    )
    optimizer = opt.Optimizer(
        list(p.parameters),
        optimizer=optax.adam(learning_rate=learning_rate),
    )

    engine = opt.OptimEngine(
        loss=loss,
        loss_monitor=opt.EmaTrainLossMonitor(effective_window=1.0),
        batches=batch_manager,
        optimizers=[optimizer],
        stopper=opt.Stopper(epochs=500, patience=50, atol=0.0, rtol=1e-4),
        seed=seed,
        initial_state=p.state,
        prune_history=True,
        show_progress=True,
        save_position_history=False,
        progress_n_updates=100,
    )
    return p, engine

# %% [markdown]
# Run the strict configuration first.

# %%
p_strict, engine_strict = build_engine(make_strict_batches(), seed=11)
result_strict = engine_strict.fit()
# Out:
# Initializing:   0%|          | 0/500 [00:00<?, ?it/s]
# Train=3409.236, Monitor=3400.277:   1%|          | 5/500 [00:00<00:46, 10.69it/s]
# Train=2606.294, Monitor=2594.454:  35%|███▌      | 175/500 [00:00<00:01, 268.21it/s]

# %% [markdown]
# Then run the automatic max-alignment configuration.

# %%
p_max, engine_max = build_engine(make_max_batches(), seed=11)
result_max = engine_max.fit()
# Out:
# Initializing:   0%|          | 0/500 [00:00<?, ?it/s]
# Train=3410.516, Monitor=3411.488:   1%|          | 5/500 [00:00<00:34, 14.23it/s]
# Train=2605.041, Monitor=2599.349:  18%|█▊        | 89/500 [00:00<00:01, 223.09it/s]

# %%
def summarize_result(result):
    position = result.position
    return {
        "m_x": float(position["m_x"]),
        "s_x": float(jnp.exp(position["s_x_transformed"])),
        "m_y": float(position["m_y"]),
        "s_y": float(jnp.exp(position["s_y_transformed"])),
        "min_monitor_epoch": result.min_monitor_epoch,
        "n_epochs": result.n_epochs,
    }


{
    "truth": {"m_x": 1.5, "s_x": 0.7, "m_y": -0.5, "s_y": 1.3},
    "strict": summarize_result(result_strict),
    "max": summarize_result(result_max),
}
# Out:
# {'truth': {'m_x': 1.5, 's_x': 0.7, 'm_y': -0.5, 's_y': 1.3},
#  'strict': {'m_x': 1.5281054973602295,
#   's_x': 0.6902655959129333,
#   'm_y': -0.5746943354606628,
#   's_y': 1.3134639263153076,
#   'min_monitor_epoch': 125,
#   'n_epochs': 175},
#  'max': {'m_x': 1.5304332971572876,
#   's_x': 0.6965134143829346,
#   'm_y': -0.581712543964386,
#   's_y': 1.3208348751068115,
#   'min_monitor_epoch': 39,
#   'n_epochs': 89}}

# %%
result_strict.plot_loss(title="Strict BatchManager loss")

# %%
result_max.plot_loss(title="Automatic max BatchManager loss")

# %% [markdown]
# Useful knobs to change while exploring: child `batch_size`, `epoch_size`, `sample_with_replacement`, `shuffle`, `Stopper` settings, and the optimizer learning rate.
