# %% [markdown]
# # Test: New Biject API
#
# This notebook tests the new `Var.biject()` and `Dist.biject_parameters()` methods that provide eager evaluation and proper handling of parameters with distributions.

# %%
import jax.numpy as jnp
import tensorflow_probability.substrates.jax.bijectors as tfb
import tensorflow_probability.substrates.jax.distributions as tfd

import liesel.model as lsl
import logging

# %% [markdown]
# ## 1. Basic Var.biject() Usage
#
# ### 1.1 Eager transformation with "auto" bijector in constructor

# %%
# Create a variable with automatic bijection in constructor
prior = lsl.Dist(tfd.HalfCauchy, loc=0.0, scale=25.0)
scale = lsl.Var(1.0, distribution=prior, name="scale", bijector="auto")

print(f"scale is weak: {scale.weak}")
print(f"scale.bijected_var: {scale.bijected_var}")
print(f"bijected_var is weak: {scale.bijected_var.weak}")
print(f"bijected_var name: {scale.bijected_var.name}")
# Out:
# scale is weak: True
# scale.bijected_var: Var(name="scale_transformed")
# bijected_var is weak: False
# bijected_var name: scale_transformed

# %% [markdown]
# ### 1.2 Explicit bijector usage with method call

# %%
# Create variable and transform with explicit bijector
prior2 = lsl.Dist(tfd.HalfCauchy, loc=0.0, scale=10.0)
scale2 = lsl.Var.new_param(2.0, distribution=prior2, name="scale2")

print(f"Before biject - scale2 is weak: {scale2.weak}")

# Apply bijection with explicit bijector
result = scale2.biject(bijector=tfb.Exp())

print(f"After biject - scale2 is weak: {scale2.weak}")
print(f"biject() returns self: {result is scale2}")
print(f"bijected_var: {scale2.bijected_var}")
# Out:
# Before biject - scale2 is weak: False
# After biject - scale2 is weak: True
# biject() returns self: True
# bijected_var: Var(name="scale2_transformed")

# %% [markdown]
# ### 1.3 Error when "auto" but no distribution

# %%
# This should raise an error
try:
    no_dist = lsl.Var.new_param(1.0, name="no_dist")
    no_dist.biject(bijector="auto")
    print("ERROR: Should have raised an exception!")
except RuntimeError as e:
    print(f"Expected error: {e}")
# Out:
# Expected error: Var(name="no_dist") has no distribution, so there is no default event space bijector to be found. No bijector was given.

# %% [markdown]
# ### 1.4 bijector=None means no transformation

# %%
# bijector=None should skip transformation
scale3 = lsl.Var.new_param(3.0, distribution=prior, name="scale3")
print(f"Before biject(None) - is weak: {scale3.weak}")

scale3.biject(bijector=None)
print(f"After biject(None) - is weak: {scale3.weak}")
print(f"bijected_var: {scale3.bijected_var}")
# Out:
# Before biject(None) - is weak: False
# After biject(None) - is weak: False
# bijected_var: None

# %% [markdown]
# ## 2. Basic Dist.biject_parameters() Usage
#
# ### 2.1 Auto transformation in Dist constructor

# %%
# Create parameters
concentration = lsl.Var.new_param(2.0, name="concentration")
rate = lsl.Var.new_param(1.0, name="rate")

print(f"Before - concentration is weak: {concentration.weak}")
print(f"Before - rate is weak: {rate.weak}")

# Create Dist with auto bijectors
gamma_dist = lsl.Dist(tfd.Gamma, concentration=concentration, rate=rate, bijectors="auto")

print(f"\nAfter - concentration is weak: {concentration.weak}")
print(f"After - rate is weak: {rate.weak}")
print(f"concentration.bijected_var: {concentration.bijected_var}")
print(f"rate.bijected_var: {rate.bijected_var}")
# Out:
# Before - concentration is weak: False
# Before - rate is weak: False
#
# After - concentration is weak: True
# After - rate is weak: True
# concentration.bijected_var: Var(name="concentration_transformed")
# rate.bijected_var: Var(name="rate_transformed")

# %% [markdown]
# ### 2.2 Dict-based bijector specification

# %%
# Create parameters
loc = lsl.Var.new_param(0.0, name="loc")
scale = lsl.Var.new_param(1.0, name="scale")

print(f"Before - loc is weak: {loc.weak}, scale is weak: {scale.weak}")

# Use dict to specify: auto for scale, None (skip) for loc
normal_dist = lsl.Dist(
    tfd.Normal,
    loc=loc,
    scale=scale,
    bijectors={"scale": "auto", "loc": None}
)

print(f"After - loc is weak: {loc.weak}, scale is weak: {scale.weak}")
print(f"Only scale was transformed: {scale.bijected_var}")
# Out:
# Before - loc is weak: False, scale is weak: False
# After - loc is weak: False, scale is weak: True
# Only scale was transformed: Var(name="scale_transformed")

# %% [markdown]
# ### 2.3 Sequence-based bijector specification (positional)

# %%
# Create parameters
loc2 = lsl.Var.new_param(0.0, name="loc2")
scale2 = lsl.Var.new_param(1.0, name="scale2")

# Use sequence: corresponds to positional parameters (loc, scale)
# Skip loc (None), auto-transform scale
normal_dist2 = lsl.Dist(
    tfd.Normal,
    loc2,  # positional
    scale2,  # positional
    bijectors=[None, "auto"]  # loc=None, scale="auto"
)

print(f"loc2 is weak: {loc2.weak}, scale2 is weak: {scale2.weak}")
print(f"Only scale2 was transformed: {scale2.bijected_var}")
# Out:
# loc2 is weak: False, scale2 is weak: True
# Only scale2 was transformed: Var(name="scale2_transformed")

# %% [markdown]
# ### 2.4 Mixed "auto" and explicit bijectors

# %%
# Use explicit bijector for one parameter, auto for another
conc = lsl.Var.new_param(3.0, name="conc")
rt = lsl.Var.new_param(2.0, name="rt")

gamma_dist2 = lsl.Dist(
    tfd.Gamma,
    concentration=conc,
    rate=rt,
    bijectors={"concentration": tfb.Softplus(), "rate": "auto"}
)

print(f"conc is weak: {conc.weak}, rt is weak: {rt.weak}")
print(f"Both transformed with different bijectors")
# Out:
# conc is weak: True, rt is weak: True
# Both transformed with different bijectors

# %% [markdown]
# ## 3. Precedence and Conflict Scenarios
#
# ### 3.1 Var-level bijector takes precedence (debug message)

# %%
logging.basicConfig(level=logging.DEBUG)

# Transform at Var level first
prior_prec = lsl.Dist(tfd.HalfCauchy, loc=0.0, scale=5.0)
prec_param = lsl.Var(1.0, distribution=prior_prec, name="prec_param", bijector="auto")

print(f"prec_param already weak: {prec_param.weak}")

# Now try to transform at Dist level with "auto" - should skip with debug log
print("\nAttempting Dist-level transformation (should see debug message):")
some_dist = lsl.Dist(tfd.Normal, loc=0.0, scale=prec_param, bijectors="auto")

print("\nNo error - Dist-level transformation was skipped")
# Out:
# prec_param already weak: True
#
# Attempting Dist-level transformation (should see debug message):
#
# No error - Dist-level transformation was skipped

# %% [markdown]
# ### 3.2 Conflict error with explicit bijector

# %%
# Transform at Var level
param_weak = lsl.Var(2.0, distribution=lsl.Dist(tfd.HalfCauchy, loc=0.0, scale=25.0), name="param_weak", bijector="auto")

# Try to apply explicit bijector at Dist level - should error
try:
    conflict_dist = lsl.Dist(
        tfd.Normal,
        loc=0.0,
        scale=param_weak,
        bijectors={"scale": tfb.Exp()}  # Explicit bijector conflicts!
    )
    print("ERROR: Should have raised an exception!")
except RuntimeError as e:
    print(f"Expected conflict error: {e}")
# Out:
# ERROR: Should have raised an exception!

# %% [markdown]
# ### 3.3 Conflict with auto_transform flag

# %%
# Set auto_transform flag
param_auto = lsl.Var.new_param(1.0, distribution=lsl.Dist(tfd.HalfCauchy, loc=0.0, scale=25.0), name="param_auto")
param_auto.auto_transform = True

# Try to apply explicit bijector at Dist level - should error
try:
    conflict_dist2 = lsl.Dist(
        tfd.Normal,
        loc=0.0,
        scale=param_auto,
        bijectors={"scale": tfb.Exp()}
    )
    print("ERROR: Should have raised an exception!")
except RuntimeError as e:
    print(f"Expected conflict error: {e}")
# Out:
# Expected conflict error: Parameter 'scale' has auto_transform=True, but explicit bijector provided. Resolve the conflict.

# %% [markdown]
# ## 4. Edge Case: Parameter with Distribution
#
# When a parameter has its own distribution, the transformation must use TransformedDistribution.

# %%
# Create a parameter with its own distribution (prior)
concentration_prior = lsl.Dist(tfd.Gamma, concentration=2.0, rate=1.0)
concentration_param = lsl.Var.new_param(2.0, distribution=concentration_prior, name="concentration_param")

print(f"concentration_param has distribution: {concentration_param.has_dist}")
print(f"concentration_param is weak: {concentration_param.weak}")

# Use this parameter in another distribution with auto bijection
# This should properly create a TransformedDistribution for the parameter
inv_gamma_dist = lsl.Dist(
    tfd.InverseGamma,
    concentration=concentration_param,
    scale=1.0,
    bijectors="auto"
)

print(f"\nAfter Dist.biject_parameters():")
print(f"concentration_param is weak: {concentration_param.weak}")
print(f"concentration_param.bijected_var: {concentration_param.bijected_var}")

# The bijected_var should still have a distribution (TransformedDistribution)
if concentration_param.bijected_var:
    print(f"bijected_var has distribution: {concentration_param.bijected_var.has_dist}")
# Out:
# concentration_param has distribution: True
# concentration_param is weak: False
#
# After Dist.biject_parameters():
# concentration_param is weak: True
# concentration_param.bijected_var: Var(name="concentration_param_transformed")
# bijected_var has distribution: True
# This demonstrates proper TransformedDistribution handling!

# %% [markdown]
# ### 4.1 Build a model with this setup

# %%
# Create a complete model with parameter that has distribution
conc_prior = lsl.Dist(tfd.Gamma, concentration=2.0, rate=1.0)
conc = lsl.Var.new_param(2.0, distribution=conc_prior, name="conc")

inv_gamma = lsl.Dist(
    tfd.InverseGamma,
    concentration=conc,
    scale=1.0,
    bijectors="auto"
)

y = lsl.Var.new_obs(jnp.array([1.0, 2.0, 3.0]), distribution=inv_gamma, name="y")

# Build model
gb = lsl.GraphBuilder().add(y)
model = gb.build_model()

print(f"Model built successfully!")
print(f"Model has {len(model.vars)} variables")
print(f"Variable names: {list(model.vars.keys())}")

# Check log prob
model.update()
print(f"\nModel log_prob: {model.log_prob}")
# Out:
# DEBUG:2025-11-21 18:39:54,755:jax._src.dispatch:198: Finished tracing + transforming convert_element_type for pjit in 0.000281334 sec
# DEBUG:jax._src.dispatch:Finished tracing + transforming convert_element_type for pjit in 0.000281334 sec
# DEBUG:2025-11-21 18:39:54,757:jax._src.interpreters.pxla:1861: Compiling jit(convert_element_type) with global shapes and types [ShapedArray(float32[3])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:jax._src.interpreters.pxla:Compiling jit(convert_element_type) with global shapes and types [ShapedArray(float32[3])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:2025-11-21 18:39:54,761:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(convert_element_type) in 0.003257275 sec
# DEBUG:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(convert_element_type) in 0.003257275 sec
# DEBUG:2025-11-21 18:39:54,763:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:jax._src.compiler:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-11-21 18:39
jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:39:54,950:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 187a49c04fe9d00307bc4f197ca31f868c89e8d4dd78bb5b07b76e2707ca9e83
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing XLA flags: 187a49c04fe9d00307bc4f197ca31f868c89e8d4dd78bb5b07b76e2707ca9e83
# DEBUG:2025-11-21 18:39:54,952:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: aa380e371b08ff0dcd1b3c71afe5a65897fc18d492ebf60407feb75501a0daca
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compile_options: aa380e371b08ff0dcd1b3c71afe5a65897fc18d492ebf60407feb75501a0daca
# DEBUG:2025-11-21 18:39:54,953:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: aba6cbfc05e42f5a18494a7bce2a2eb1f84a3596d5bab72a7c569def037b51f4
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compile_options: aba6cbfc05e42f5a18494a7bce2a2eb1f84a3596d5bab72a7c569def037b51f4
# DEBUG:2025-11-21 18:39:54,954:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:2025-11-21 18:39:54,955:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 36f9e6dd885f13de202b776084e12c779f79f9a8c52e672fc86fd661f4ff56be
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing accelerator_config: 36f9e6dd885f13de202b776084e12c779f79f9a8c52e672fc86fd661f4ff56be
# DEBUG:2025-11-21 18:39:54,956:jax._src.cache_key:156: get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:2025-11-21 18:39:54,957:jax._src.cache_key:162: get_cache_key hash after serializing compression: 78e6ada97e531393a8933ef64437e96a9209296b80646d3c7a6ec31eb0840403
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compression: 78e6ada97e531393a8933ef64437e96a9209296b80646d3c7a6ec31eb0840403
# DEBUG:2025-11-21 18:39:54,957:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:39:54,958:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 78e6ada97e531393a8933ef64437e96a9209296b80646d3c7a6ec31eb0840403
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing custom_hook: 78e6ada97e531393a8933ef64437e96a9209296b80646d3c7a6ec31eb0840403
# DEBUG:2025-11-21 18:39:54,959:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:jax._src.compilation_cache:get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-11-21 18:39:54,960:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_log' with key 'jit_log-78e6ada97e531393a8933ef64437e96a9209296b80646d3c7a6ec31eb0840403'
# DEBUG:jax._src.compiler:PERSISTENT COMPILATION CACHE MISS for 'jit_log' with key 'jit_log-78e6ada97e531393a8933ef64437e96a9209296b80646d3c7a6ec31eb0840403'
# DEBUG:2025-11-21 18:39:54,981:jax._src.compiler:831: Not writing persistent cache entry for 'jit_log' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:jax._src.compiler:Not writing persistent cache entry for 'jit_log' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:2025-11-21 18:39:54,984:jax._src.dispatch:198: Finished XLA compilation of jit(log) in 0.041147947 sec
# DEBUG:jax._src.dispatch:Finished XLA compilation of jit(log) in 0.041147947 sec
# DEBUG:2025-11-21 18:39:54,987:jax._src.dispatch:198: Finished tracing + transforming mul for pjit in 0.000478029 sec
# DEBUG:jax._src.dispatch:Finished tracing + transforming mul for pjit in 0.000478029 sec
# DEBUG:2025-11-21 18:39:54,989:jax._src.interpreters.pxla:1861: Compiling jit(mul) with global shapes and types [ShapedArray(float32[]), ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:jax._src.interpreters.pxla:Compiling jit(mul) with global shapes and types [ShapedArray(float32[]), ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-11-21 18:39:54,995:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(mul) in 0.004253149 sec
# DEBUG:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(mul) in 0.004253149 sec
# DEBUG:2025-11-21 18:39:54,996:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:jax._src.compiler:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-11-21 18:39:54,998:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:jax._src.compiler:get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-11-21 18:39:54,999:jax._src.cache_key:156: get_cache_key hash of serialized computation: d920592ba97a50901249f7ae1cfbd54bc17d7349a54e5db804fb76b33a672942
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized computation: d920592ba97a50901249f7ae1cfbd54bc17d7349a54e5db804fb76b33a672942
# DEBUG:2025-11-21 18:39:55,001:jax._src.cache_key:162: get_cache_key hash after serializing computation: d920592ba97a50901249f7ae1cfbd54bc17d7349a54e5db804fb76b33a672942
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing computation: d920592ba97a50901249f7ae1cfbd54bc17d7349a54e5db804fb76b33a672942
# DEBUG:2025-11-21 18:39:55,002:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-11-21 18:39:55,003:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 620dc6a530606cc1aade962261dbfd0fbd1bc3279129998a1afd50bd8ced7703
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing jax_lib version: 620dc6a530606cc1aade962261dbfd0fbd1bc3279129998a1afd50bd8ced7703
# DEBUG:2025-11-21 18:39:55,003:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-11-21 18:39:55,004:jax._src.cache_key:162: get_cache_key hash after serializing backend version: c5698d42bd18d408034dcfc856cd7372b2f7a95ccbd5ff7ed3d1e5d61665d22d
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing backend version: c5698d42bd18d408034dcfc856cd7372b2f7a95ccbd5ff7ed3d1e5d61665d22d
# DEBUG:2025-11-21 18:39:55,005:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:39:55,006:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: c5698d42bd18d408034dcfc856cd7372b2f7a95ccbd5ff7ed3d1e5d61665d22d
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing XLA flags: c5698d42bd18d408034dcfc856cd7372b2f7a95ccbd5ff7ed3d1e5d61665d22d
# DEBUG:2025-11-21 18:39:55,007:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 8d8e388f48e4efc23534e450e33eafda61382f4d9c61c2c29fc11dd20315a2df
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compile_options: 8d8e388f48e4efc23534e450e33eafda61382f4d9c61c2c29fc11dd20315a2df
# DEBUG:2025-11-21 18
sec
# DEBUG:jax._src.dispatch:Finished tracing + transforming subtract for pjit in 0.000602245 sec
# DEBUG:2025-11-21 18:39:55,604:jax._src.interpreters.pxla:1861: Compiling jit(subtract) with global shapes and types [ShapedArray(float32[3]), ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:jax._src.interpreters.pxla:Compiling jit(subtract) with global shapes and types [ShapedArray(float32[3]), ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-11-21 18:39:55,610:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(subtract) in 0.004577637 sec
# DEBUG:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(subtract) in 0.004577637 sec
# DEBUG:2025-11-21 18:39:55,612:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:jax._src.compiler:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-11-21 18:39:55,613:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:jax._src.compiler:get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-11-21 18:39:55,614:jax._src.cache_key:156: get_cache_key hash of serialized computation: ba180d94ded14a7c6eca9f8478079582e29bef428737345d0b27e5987a425257
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized computation: ba180d94ded14a7c6eca9f8478079582e29bef428737345d0b27e5987a425257
# DEBUG:2025-11-21 18:39:55,615:jax._src.cache_key:162: get_cache_key hash after serializing computation: ba180d94ded14a7c6eca9f8478079582e29bef428737345d0b27e5987a425257
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing computation: ba180d94ded14a7c6eca9f8478079582e29bef428737345d0b27e5987a425257
# DEBUG:2025-11-21 18:39:55,616:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-11-21 18:39:55,617:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 64a2be88a8649ef8da42079c77902bd9b1d8d1018840813ba6c7d10162172213
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing jax_lib version: 64a2be88a8649ef8da42079c77902bd9b1d8d1018840813ba6c7d10162172213
# DEBUG:2025-11-21 18:39:55,618:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-11-21 18:39:55,619:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 219838e90106417e2703d614ee4c76b8ea4ac5e1725e59c2e38daa1879ee4875
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing backend version: 219838e90106417e2703d614ee4c76b8ea4ac5e1725e59c2e38daa1879ee4875
# DEBUG:2025-11-21 18:39:55,620:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:39:55,621:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 219838e90106417e2703d614ee4c76b8ea4ac5e1725e59c2e38daa1879ee4875
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing XLA flags: 219838e90106417e2703d614ee4c76b8ea4ac5e1725e59c2e38daa1879ee4875
# DEBUG:2025-11-21 18:39:55,622:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 8d8e388f48e4efc23534e450e33eafda61382f4d9c61c2c29fc11dd20315a2df
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compile_options: 8d8e388f48e4efc23534e450e33eafda61382f4d9c61c2c29fc11dd20315a2df
# DEBUG:2025-11-21 18:39:55,623:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 14cae965df3e9263fa12d5bdc481b45404567bb23b6de1947f4a780778aa4f3e
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compile_options: 14cae965df3e9263fa12d5bdc481b45404567bb23b6de1947f4a780778aa4f3e
# DEBUG:2025-11-21 18:39:55,624:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:2025-11-21 18:39:55,625:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: bde598ae9dd6a04f0da992f81ea9f5c160b88b9753f1bc50072a226a847719f1
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing accelerator_config: bde598ae9dd6a04f0da992f81ea9f5c160b88b9753f1bc50072a226a847719f1
# DEBUG:2025-11-21 18:39:55,625:jax._src.cache_key:156: get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:2025-11-21 18:39:55,626:jax._src.cache_key:162: get_cache_key hash after serializing compression: f6fc1424aceb5134c2d9f956208eadaf7942816536e067c91a861b19241c844f
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compression: f6fc1424aceb5134c2d9f956208eadaf7942816536e067c91a861b19241c844f
# DEBUG:2025-11-21 18:39:55,627:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:39:55,628:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: f6fc1424aceb5134c2d9f956208eadaf7942816536e067c91a861b19241c844f
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing custom_hook: f6fc1424aceb5134c2d9f956208eadaf7942816536e067c91a861b19241c844f
# DEBUG:2025-11-21 18:39:55,629:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:jax._src.compilation_cache:get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-11-21 18:39:55,630:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_subtract' with key 'jit_subtract-f6fc1424aceb5134c2d9f956208eadaf7942816536e067c91a861b19241c844f'
# DEBUG:jax._src.compiler:PERSISTENT COMPILATION CACHE MISS for 'jit_subtract' with key 'jit_subtract-f6fc1424aceb5134c2d9f956208eadaf7942816536e067c91a861b19241c844f'
# DEBUG:2025-11-21 18:39:55,650:jax._src.compiler:831: Not writing persistent cache entry for 'jit_subtract' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:jax._src.compiler:Not writing persistent cache entry for 'jit_subtract' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:2025-11-21 18:39:55,651:jax._src.dispatch:198: Finished XLA compilation of jit(subtract) in 0.037086010 sec
# DEBUG:jax._src.dispatch:Finished XLA compilation of jit(subtract) in 0.037086010 sec
# DEBUG:2025-11-21 18:39:55,654:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000591516 sec
# DEBUG:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.000591516 sec
# DEBUG:2025-11-21 18:39:55,655:jax._src.interpreters.pxla:1861: Compiling jit(_reduce_sum) with global shapes and types [ShapedArray(float32[3])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:jax._src.interpreters.pxla:Compiling jit(_reduce_sum) with global shapes and types [ShapedArray(float32[3])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:2025-11-21 18:39:55,662:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(_reduce_sum) in 0.005903006 sec
# DEBUG:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(_reduce_sum) in 0.005903006 sec
# DEBUG:2025-11-21 18:39:55,664:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:jax._src.compiler:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-11-21 18:39:55,666:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:jax._src.compiler:get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-11-21 18:39:55,667:jax._src.cache_key:156: get_cache_key hash of serialized computation: 357691c9558c3d15b31798991bbbc9959f0a74f26bc4679eda7765a3450da510
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized computation: 357691c9558c3d15b31798991bbbc9959f0a74f26bc4679eda7765a3450da510
# DEBUG:2025-11-21 18:39:55,668:jax._src.cache_key:162: get_cache_key hash after serializing computation: 357691c9558c3d15b31798991bbbc9959f0a74f26bc4679eda7765a3450da510
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing computation: 357691c9558c3d15b31798991bbbc9959f0a74f26bc4679eda7765a3450da510
# DEBUG:2025-11-21 18:39:55,669:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-11-21 18:39:55,670:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: f7caf3730209fbcf1f03c98a8921917be8c0932bda5219c5bd3a8ff2cdf382ab
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing jax_lib version: f7caf3730209fbcf1f03c98a8921917be8c0932bda5219c5bd3a8ff2cdf382ab
# DEBUG:2025-11-21 18:39:55,670:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-11-21 18:39:55,671:jax._src.cache_key:162: get_cache_key hash after serializing backend version: b0583f3436957638a2e63e24b06fa03aff1104a1416a5d05c0757ea19f17fb6e
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing backend version: b0583f3436957638a2e63e24b06fa03aff1104a1416a5d05c0757ea19f17fb6e
# DEBUG:2025-11-21 18:39:55,672:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:39:55,673:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: b0583f3436957638a2e63e24b06fa03aff1104a1416a5d05c0757ea19f17fb6e
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing XLA flags: b0583f3436957638a2e63e24b06fa03aff1104a1416a5d05c0757ea19f17fb6e
# DEBUG:2025-11-21 18:39:55,674:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: aa380e371b08ff0dcd1b3c71afe5a65897fc18d492ebf60407feb75501a0daca
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compile_options: aa380e371b08ff0dcd1b3c71afe5a65897fc18d492ebf60407feb75501a0daca
# DEBUG:2025-11-21 18:39:55,675:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: d4ec09c960f23c6dc4ce28b1a683b90b9368b8e87a4b0b4102db6c6695f74247
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compile_options: d4ec09c960f23c6dc4ce28b1a683b90b9368b8e87a4b0b4102db6c6695f74247
# DEBUG:2025-11-21 18:39:55,677:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:2025-11-21 18:39:55,678:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 67dd8e4157fa3f4cc41706fed1b543da7010c87f97466a21df315f2e437ad866
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing accelerator_config: 67dd8e4157fa3f4cc41706fed1b543da7010c87f97466a21df315f2e437ad866
# DEBUG:2025-11-21 18:39:55,678:jax._src.cache_key:156: get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:2025-11-21 18:39:55,679:jax._src.cache_key:162: get_cache_key hash after serializing compression: d912cf35fb6c6ff1ccdf865c2dad70da67d040da4cde7b9d581dce4079fdbba0
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compression: d912cf35fb6c6ff1ccdf865c2dad70da67d040da4cde7b9d581dce4079fdbba0
# DEBUG:2025-11-21 18:39:55,680:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:39:55,681:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: d912cf35fb6c6ff1ccdf865c2dad70da67d040da4cde7b9d581dce4079fdbba0
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing custom_hook: d912cf35fb6c6ff1ccdf865c2dad70da67d040da4cde7b9d581dce4079fdbba0
# DEBUG:2025-11-21 18:39:55,682:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:jax._src.compilation_cache:get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-11-21 18:39:55,683:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit__reduce_sum' with key 'jit__reduce_sum-d912cf35fb6c6ff1ccdf865c2dad70da67d040da4cde7b9d581dce4079fdbba0'
# DEBUG:jax._src.compiler:PERSISTENT COMPILATION CACHE MISS for 'jit__reduce_sum' with key 'jit__reduce_sum-d912cf35fb6c6ff1ccdf865c2dad70da67d040da4cde7b9d581dce4079fdbba0'
# DEBUG:2025-11-21 18:39:55,703:jax._src.compiler:831: Not writing persistent cache entry for 'jit__reduce_sum' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:jax._src.compiler:Not writing persistent cache entry for 'jit__reduce_sum' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:2025-11-21 18:39:55,705:jax._src.dispatch:198: Finished XLA compilation of jit(_reduce_sum) in 0.038986444 sec
# DEBUG:jax._src.dispatch:Finished XLA compilation of jit(_reduce_sum) in 0.038986444 sec
# Model built successfully!
# Model has 3 variables
# Variable names: ['y', 'conc', 'conc_transformed']
#
# Model log_prob: -8.66087818145752

# %% [markdown]
# ## 5. Method Chaining
#
# Both methods return `self`, enabling fluent API usage.

# %%
# Var.biject() returns self
chain_var = lsl.Var.new_param(1.0, distribution=lsl.Dist(tfd.HalfCauchy, loc=0.0, scale=25.0), name="chain_var")
result = chain_var.biject(bijector="auto")

print(f"biject() returns self: {result is chain_var}")
print(f"Can chain methods: weak={chain_var.weak}")

# Dist.biject_parameters() returns self
p1 = lsl.Var.new_param(1.0, name="p1")
p2 = lsl.Var.new_param(2.0, name="p2")
dist_chain = lsl.Dist(tfd.Gamma, concentration=p1, rate=p2)
result2 = dist_chain.biject_parameters(bijectors="auto")

print(f"biject_parameters() returns self: {result2 is dist_chain}")
# Out:
# biject() returns self: True
# Can chain methods: weak=True
# biject_parameters() returns self: True

# %% [markdown]
# ## 6. Backward Compatibility
#
# ### 6.1 Old `transform()` method still works

# %%
# Use old transform() method
old_var = lsl.Var.new_param(1.0, distribution=lsl.Dist(tfd.HalfCauchy, loc=0.0, scale=25.0), name="old_var")
transformed_var = old_var.transform(bijector=tfb.Exp())

print(f"old_var is weak: {old_var.weak}")
print(f"transform() returns the transformed variable: {transformed_var}")
print(f"transformed_var.name: {transformed_var.name}")
# Out:
# old_var is weak: True
# transform() returns the transformed variable: Var(name="old_var_transformed")
# transformed_var.name: old_var_transformed
# Old API still works!

# %% [markdown]
# ### 6.2 `auto_transform` flag still works

# %%
# Use auto_transform flag (lazy evaluation)
lazy_var = lsl.Var.new_param(1.0, distribution=lsl.Dist(tfd.HalfCauchy, loc=0.0, scale=25.0), name="lazy_var")
lazy_var.auto_transform = True

print(f"Before model building - lazy_var is weak: {lazy_var.weak}")

# Create a simple model
y_lazy = lsl.Var.new_obs(jnp.array([1.0, 2.0]), distribution=lsl.Dist(tfd.Normal, loc=0.0, scale=lazy_var), name="y_lazy")
gb_lazy = lsl.GraphBuilder().add(y_lazy)
model_lazy = gb_lazy.build_model()

print(f"After model building - lazy_var is weak: {lazy_var.weak}")
print(f"Lazy evaluation with auto_transform still works!")
print(f"Model variables: {list(model_lazy.vars.keys())}")
# Out:
# DEBUG:2025-11-21 18:46:51,167:jax._src.dispatch:198: Finished tracing + transforming convert_element_type for pjit in 0.000802994 sec
# DEBUG:jax._src.dispatch:Finished tracing + transforming convert_element_type for pjit in 0.000802994 sec
# DEBUG:2025-11-21 18:46:51,168:jax._src.interpreters.pxla:1861: Compiling jit(convert_element_type) with global shapes and types [ShapedArray(float32[2])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:jax._src.interpreters.pxla:Compiling jit(convert_element_type) with global shapes and types [ShapedArray(float32[2])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:2025-11-21 18:46:51,173:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(convert_element_type) in 0.004088640 sec
# DEBUG:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(convert_element_type) in 0.004088640 sec
# DEBUG:2025-11-21 18:46:51,175:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:jax._src.compiler:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-11-21 18:46:51,176:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:jax._src.compiler:get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-11-21 18:46:51,177:jax._src.cache_key:156: get_cache_key hash of serialized computation: 5e2c5f8afbf7cd7e05c852e970f1691c7d54bcf73eb61135934e9a9347abe160
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized computation: 5e2c5f8afbf7cd7e05c852e970f1691c7d54bcf73eb61135934e9a9347abe160
# DEBUG:2025-11-21 18:46:51,178:jax._src.cache_key:162: get_cache_key hash after serializing computation: 5e2c5f8afbf7cd7e05c852e970f1691c7d54bcf73eb61135934e9a9347abe160
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing computation: 5e2c5f8afbf7cd7e05c852e970f1691c7d54bcf73eb61135934e9a9347abe160
# DEBUG:2025-11-21 18:46:51,179:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-11-21 18:46:51,181:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 8c3d155e976b38e48fb3f2b7894753e7f49517462d283901e867cc1dc297374f
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing jax_lib version: 8c3d155e976b38e48fb3f2b7894753e7f49517462d283901e867cc1dc297374f
# DEBUG:2025-11-21 18:46:51,182:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-11-21 18:46:51,183:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 1f9084b9134f2e1c7f4aab8ac27888d688cea1e3a488b712f7fa4a6b5f5ca6c8
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing backend version: 1f9084b9134f2e1c7f4aab8ac27888d688cea1e3a488b712f7fa4a6b5f5ca6c8
# DEBUG:2025-11-21 18:46:51,184:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,185:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 1f9084b9134f2e1c7f4aab8ac27888d688cea1e3a488b712f7fa4a6b5f5ca6c8
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing XLA flags: 1f9084b9134f2e1c7f4aab8ac27888d688cea1e3a488b712f7fa4a6b5f5ca6c8
# DEBUG:2025-11-21 18:46:51,186:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: aa380e371b08ff0dcd1b3c71afe5a65897fc18d492ebf60407feb75501a0daca
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compile_options: aa380e371b08ff0dcd1b3c71afe5a65897fc18d492ebf60407feb75501a0daca
# DEBUG:2025-11-21 18:46:51,187:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 178547e10bd169f676b342a1573df58b7429d9cc944d4c6a116a1b0f2af190ea
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compile_options: 178547e10bd169f676b342a1573df58b7429d9cc944d4c6a116a1b0f2af190ea
# DEBUG:2025-11-21 18:46:51,188:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:2025-11-21 18:46:51,189:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 1e285b30e94fc27db83c3c28bbc4be774940f5376e68a3a3283bed0cf8b73cbd
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing accelerator_config: 1e285b30e94fc27db83c3c28bbc4be774940f5376e68a3a3283bed0cf8b73cbd
# DEBUG:2025-11-21 18:46:51,189:jax._src.cache_key:156: get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:2025-11-21 18:46:51,190:jax._src.cache_key:162: get_cache_key hash after serializing compression: fa772a0c6af92f29ddf1b594362bd4172d2c95d8cffb8aaf72a3a075118e009f
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compression: fa772a0c6af92f29ddf1b594362bd4172d2c95d8cffb8aaf72a3a075118e009f
# DEBUG:2025-11-21 18:46:51,192:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,193:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: fa772a0c6af92f29ddf1b594362bd4172d2c95d8cffb8aaf72a3a075118e009f
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing custom_hook: fa772a0c6af92f29ddf1b594362bd4172d2c95d8cffb8aaf72a3a075118e009f
# DEBUG:2025-11-21 18:46:51,194:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:jax._src.compilation_cache:get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-11-21 18:46:51,195:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_convert_element_type' with key 'jit_convert_element_type-fa772a0c6af92f29ddf1b594362bd4172d2c95d8cffb8aaf72a3a075118e009f'
# DEBUG:jax._src.compiler:PERSISTENT COMPILATION CACHE MISS for 'jit_convert_element_type' with key 'jit_convert_element_type-fa772a0c6af92f29ddf1b594362bd4172d2c95d8cffb8aaf72a3a075118e009f'
# DEBUG:2025-11-21 18:46:51,206:jax._src.compiler:831: Not writing persistent cache entry for 'jit_convert_element_type' because it took < 1.00 seconds to compile (0.01s)
# DEBUG:jax._src.compiler:Not writing persistent cache entry for 'jit_convert_element_type' because it took < 1.00 seconds to compile (0.01s)
# DEBUG:2025-11-21 18:46:51,208:jax._src.dispatch:198: Finished XLA compilation of jit(convert_element_type) in 0.031149149 sec
# DEBUG:jax._src.dispatch:Finished XLA compilation of jit(convert_element_type) in 0.031149149 sec
# DEBUG:2025-11-21 18:46:51,237:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000447512 sec
# DEBUG:jax._src.dispatch:Finished tracing + transforming multiply for pjit in 0.000447512 sec
# DEBUG:2025-11-21 18:46:51,239:jax._src.interpreters.pxla:1861: Compiling jit(multiply) with global shapes and types [ShapedArray(float32[], weak_type=True), ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:jax._src.interpreters.pxla:Compiling jit(multiply) with global shapes and types [ShapedArray(float32[], weak_type=True), ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-11-21 18:46:51,246:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(multiply) in 0.005545855 sec
# DEBUG:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(multiply) in 0.005545855 sec
# DEBUG:2025-11-21 18:46:51,248:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:jax._src.compiler:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-11-21 18:46:51,250:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:jax._src.compiler:get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-11-21 18:46:51,251:jax._src.cache_key:156: get_cache_key hash of serialized computation: 94bf25a9bdd55bb96499a96b09b05938dee0af1d6cb1e8fe558ceca2199f36d8
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized computation: 94bf25a9bdd55bb96499a96b09b05938dee0af1d6cb1e8fe558ceca2199f36d8
# DEBUG:2025-11-21 18:46:51,252:jax._src.cache_key:162: get_cache_key hash after serializing computation: 94bf25a9bdd55bb96499a96b09b05938dee0af1d6cb1e8fe558ceca2199f36d8
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing computation: 94bf25a9bdd55bb96499a96b09b05938dee0af1d6cb1e8fe558ceca2199f36d8
# DEBUG:2025-11-21 18:46:51,253:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-11-21 18:46:51,254:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 26f93d06d57f272f3968d094094ceb8fae368ab6d439f3cc34bdf6a4e64e4147
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing jax_lib version: 26f93d06d57f272f3968d094094ceb8fae368ab6d439f3cc34bdf6a4e64e4147
# DEBUG:2025-11-21 18:46:51,255:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-11-21 18:46:51,255:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 034567b5461bf8dd0ab2e7acf22efb7815d639d44c61a52901abd0999b647b33
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing backend version: 034567b5461bf8dd0ab2e7acf22efb7815d639d44c61a52901abd0999b647b33
# DEBUG:2025-11-21 18:46:51,256:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,257:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 034567b5461bf8dd0ab2e7acf22efb7815d639d44c61a52901abd0999b647b33
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing XLA flags: 034567b5461bf8dd0ab2e7acf22efb7815d639d44c61a52901abd0999b647b33
# DEBUG:2025-11-21 18:46:51,258:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 8d8e388f48e4efc23534e450e33eafda61382f4d9c61c2c29fc11dd20315a2df
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compile_options: 8d8e388f48e4efc23534e450e33eafda61382f4d9c61c2c29fc11dd20315a2df
# DEBUG:2025-11-21 18:46:51,258:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: f141a39922e0318c8876eca8fb6bfd29d5486b5b3470f9121598aa1412bf49ca
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compile_options: f141a39922e0318c8876eca8fb6bfd29d5486b5b3470f9121598aa1412bf49ca
# DEBUG:2025-11-21 18:46:51,259:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:2025-11-21 18:46:51,260:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 75cf54d1ea571f1f21cf6af426b8fa5f5a5ba0f86e30a549a299e1aa0fb0de9d
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing accelerator_config: 75cf54d1ea571f1f21cf6af426b8fa5f5a5ba0f86e30a549a299e1aa0fb0de9d
# DEBUG:2025-11-21 18:46:51,261:jax._src.cache_key:156: get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:2025-11-21 18:46:51,261:jax._src.cache_key:162: get_cache_key hash after serializing compression: 8d812e11adfdbfaa08c0e3b821c03b1f5c899818a9fcb9c1154a421a46d20296
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compression: 8d812e11adfdbfaa08c0e3b821c03b1f5c899818a9fcb9c1154a421a46d20296
# DEBUG:2025-11-21 18:46:51,262:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,263:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 8d812e11adfdbfaa08c0e3b821c03b1f5c899818a9fcb9c1154a421a46d20296
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing custom_hook: 8d812e11adfdbfaa08c0e3b821c03b1f5c899818a9fcb9c1154a421a46d20296
# DEBUG:2025-11-21 18:46:51,263:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:jax._src.compilation_cache:get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-11-21 18:46:51,264:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_multiply' with key 'jit_multiply-8d812e11adfdbfaa08c0e3b821c03b1f5c899818a9fcb9c1154a421a46d20296'
# DEBUG:jax._src.compiler:PERSISTENT COMPILATION CACHE MISS for 'jit_multiply' with key 'jit_multiply-8d812e11adfdbfaa08c0e3b821c03b1f5c899818a9fcb9c1154a421a46d20296'
# DEBUG:2025-11-21 18:46:51,280:jax._src.compiler:831: Not writing persistent cache entry for 'jit_multiply' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:jax._src.compiler:Not writing persistent cache entry for 'jit_multiply' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:2025-11-21 18:46:51,282:jax._src.dispatch:198: Finished XLA compilation of jit(multiply) in 0.031993866 sec
# DEBUG:jax._src.dispatch:Finished XLA compilation of jit(multiply) in 0.031993866 sec
# DEBUG:2025-11-21 18:46:51,287:jax._src.dispatch:198: Finished tracing + transforming true_divide for pjit in 0.000358105 sec
# DEBUG:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.000358105 sec
# DEBUG:2025-11-21 18:46:51,288:jax._src.interpreters.pxla:1861: Compiling jit(true_divide) with global shapes and types [ShapedArray(float32[]), ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:jax._src.interpreters.pxla:Compiling jit(true_divide) with global shapes and types [ShapedArray(float32[]), ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-11-21 18:46:51,293:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(true_divide) in 0.003816605 sec
# DEBUG:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(true_divide) in 0.003816605 sec
# DEBUG:2025-11-21 18:46:51,295:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:jax._src.compiler:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-11-21 18:46:51,296:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:jax._src.compiler:get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-11-21 18:46:51,298:jax._src.cache_key:156: get_cache_key hash of serialized computation: 605bf3ab5fee97679bfecad122954df65cc3aa84bde9e2209499dfd458a166b3
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized computation: 605bf3ab5fee97679bfecad122954df65cc3aa84bde9e2209499dfd458a166b3
# DEBUG:2025-11-21 18:46:51,299:jax._src.cache_key:162: get_cache_key hash after serializing computation: 605bf3ab5fee97679bfecad122954df65cc3aa84bde9e2209499dfd458a166b3
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing computation: 605bf3ab5fee97679bfecad122954df65cc3aa84bde9e2209499dfd458a166b3
# DEBUG:2025-11-21 18:46:51,300:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-11-21 18:46:51,301:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: aec46b962c950caa0ddc978c5eb5b66a598280d33a490926ad2529d41a4b98ae
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing jax_lib version: aec46b962c950caa0ddc978c5eb5b66a598280d33a490926ad2529d41a4b98ae
# DEBUG:2025-11-21 18:46:51,301:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-11-21 18:46:51,302:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 89f82cf6d8ba829f2e187cb797a24d3529eef4b3c4ca6626410cfbcdd7cf0654
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing backend version: 89f82cf6d8ba829f2e187cb797a24d3529eef4b3c4ca6626410cfbcdd7cf0654
# DEBUG:2025-11-21 18:46:51,303:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,303:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 89f82cf6d8ba829f2e187cb797a24d3529eef4b3c4ca6626410cfbcdd7cf0654
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing XLA flags: 89f82cf6d8ba829f2e187cb797a24d3529eef4b3c4ca6626410cfbcdd7cf0654
# DEBUG:2025-11-21 18:46:51,304:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 8d8e388f48e4efc23534e450e33eafda61382f4d9c61c2c29fc11dd20315a2df
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compile_options: 8d8e388f48e4efc23534e450e33eafda61382f4d9c61c2c29fc11dd20315a2df
# DEBUG:2025-11-21 18:46:51,305:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 5992aaa590729eb1c0bfbff4d665227382fa5eeeee95eed3cd97f3e0a7a697af
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compile_options: 5992aaa590729eb1c0bfbff4d665227382fa5eeeee95eed3cd97f3e0a7a697af
# DEBUG:2025-11-21 18:46:51,306:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:2025-11-21 18:46:51,307:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 05e3bb3d6025b95258a67fa0e9141e76ed8aa17665c5f553242255eb4bd03b88
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing accelerator_config: 05e3bb3d6025b95258a67fa0e9141e76ed8aa17665c5f553242255eb4bd03b88
# DEBUG:2025-11-21 18:46:51,307:jax._src.cache_key:156: get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:2025-11-21 18:46:51,308:jax._src.cache_key:162: get_cache_key hash after serializing compression: dfb16f3d5c91b4d09914b16980843353a63bdaef4e16bb0fef27d540b802993d
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compression: dfb16f3d5c91b4d09914b16980843353a63bdaef4e16bb0fef27d540b802993d
# DEBUG:2025-11-21 18:46:51,311:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,312:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: dfb16f3d5c91b4d09914b16980843353a63bdaef4e16bb0fef27d540b802993d
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing custom_hook: dfb16f3d5c91b4d09914b16980843353a63bdaef4e16bb0fef27d540b802993d
# DEBUG:2025-11-21 18:46:51,313:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:jax._src.compilation_cache:get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-11-21 18:46:51,314:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_true_divide' with key 'jit_true_divide-dfb16f3d5c91b4d09914b16980843353a63bdaef4e16bb0fef27d540b802993d'
# DEBUG:jax._src.compiler:PERSISTENT COMPILATION CACHE MISS for 'jit_true_divide' with key 'jit_true_divide-dfb16f3d5c91b4d09914b16980843353a63bdaef4e16bb0fef27d540b802993d'
# DEBUG:2025-11-21 18:46:51,330:jax._src.compiler:831: Not writing persistent cache entry for 'jit_true_divide' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:jax._src.compiler:Not writing persistent cache entry for 'jit_true_divide' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:2025-11-21 18:46:51,332:jax._src.dispatch:198: Finished XLA compilation of jit(true_divide) in 0.034586668 sec
# DEBUG:jax._src.dispatch:Finished XLA compilation of jit(true_divide) in 0.034586668 sec
# DEBUG:2025-11-21 18:46:51,337:jax._src.dispatch:198: Finished tracing + transforming integer_pow for pjit in 0.001711369 sec
# DEBUG:jax._src.dispatch:Finished tracing + transforming integer_pow for pjit in 0.001711369 sec
# DEBUG:2025-11-21 18:46:51,339:jax._src.interpreters.pxla:1861: Compiling jit(integer_pow) with global shapes and types [ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:jax._src.interpreters.pxla:Compiling jit(integer_pow) with global shapes and types [ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:2025-11-21 18:46:51,346:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(integer_pow) in 0.004864216 sec
# DEBUG:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(integer_pow) in 0.004864216 sec
# DEBUG:2025-11-21 18:46:51,348:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:jax._src.compiler:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-11-21 18:46:51,349:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:jax._src.compiler:get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-11-21 18:46:51,350:jax._src.cache_key:156: get_cache_key hash of serialized computation: 12d7fbdbe048e18e3e01af36b74540e31425fef2a9d56c481cb813c3001bb3c5
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized computation: 12d7fbdbe048e18e3e01af36b74540e31425fef2a9d56c481cb813c3001bb3c5
# DEBUG:2025-11-21 18:46:51,351:jax._src.cache_key:162: get_cache_key hash after serializing computation: 12d7fbdbe048e18e3e01af36b74540e31425fef2a9d56c481cb813c3001bb3c5
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing computation: 12d7fbdbe048e18e3e01af36b74540e31425fef2a9d56c481cb813c3001bb3c5
# DEBUG:2025-11-21 18:46:51,352:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-11-21 18:46:51,353:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 849513e7e6a54e7c47e89243526e490e96efdd4862b33e66110143c7eb93d9f8
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing jax_lib version: 849513e7e6a54e7c47e89243526e490e96efdd4862b33e66110143c7eb93d9f8
# DEBUG:2025-11-21 18:46:51,353:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-11-21 18:46:51,354:jax._src.cache_key:162: get_cache_key hash after serializing backend version: e1a72a70dbd301f9628118d1e044fbda265debbd9423c6c7c8618bbb41303a6d
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing backend version: e1a72a70dbd301f9628118d1e044fbda265debbd9423c6c7c8618bbb41303a6d
# DEBUG:2025-11-21 18:46:51,355:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,356:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: e1a72a70dbd301f9628118d1e044fbda265debbd9423c6c7c8618bbb41303a6d
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing XLA flags: e1a72a70dbd301f9628118d1e044fbda265debbd9423c6c7c8618bbb41303a6d
# DEBUG:2025-11-21 18:46:51,357:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: aa380e371b08ff0dcd1b3c71afe5a65897fc18d492ebf60407feb75501a0daca
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compile_options: aa380e371b08ff0dcd1b3c71afe5a65897fc18d492ebf60407feb75501a0daca
# DEBUG:2025-11-21 18:46:51,357:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 6dea55990a7d27a8611d565a55b9964a8d325b2b161cd776d5455493255c334c
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compile_options: 6dea55990a7d27a8611d565a55b9964a8d325b2b161cd776d5455493255c334c
# DEBUG:2025-11-21 18:46:51,358:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:2025-11-21 18:46:51,359:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: b7d72cf3882e6e2bc905fd1ac4336b65f79c0ace76e5845cad7ad1411aaff571
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing accelerator_config: b7d72cf3882e6e2bc905fd1ac4336b65f79c0ace76e5845cad7ad1411aaff571
# DEBUG:2025-11-21 18:46:51,360:jax._src.cache_key:156: get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:2025-11-21 18:46:51,360:jax._src.cache_key:162: get_cache_key hash after serializing compression: a4e52eefe0ca26c38715e776627137fce3ae7b8f70e20973e3aeeded18738579
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compression: a4e52eefe0ca26c38715e776627137fce3ae7b8f70e20973e3aeeded18738579
# DEBUG:2025-11-21 18:46:51,361:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,362:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: a4e52eefe0ca26c38715e776627137fce3ae7b8f70e20973e3aeeded18738579
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing custom_hook: a4e52eefe0ca26c38715e776627137fce3ae7b8f70e20973e3aeeded18738579
# DEBUG:2025-11-21 18:46:51,363:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:jax._src.compilation_cache:get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-11-21 18:46:51,364:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_integer_pow' with key 'jit_integer_pow-a4e52eefe0ca26c38715e776627137fce3ae7b8f70e20973e3aeeded18738579'
# DEBUG:jax._src.compiler:PERSISTENT COMPILATION CACHE MISS for 'jit_integer_pow' with key 'jit_integer_pow-a4e52eefe0ca26c38715e776627137fce3ae7b8f70e20973e3aeeded18738579'
# Before model building - lazy_var is weak: False
# DEBUG:2025-11-21 18:46:51,382:jax._src.compiler:831: Not writing persistent cache entry for 'jit_integer_pow' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:jax._src.compiler:Not writing persistent cache entry for 'jit_integer_pow' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:2025-11-21 18:46:51,384:jax._src.dispatch:198: Finished XLA compilation of jit(integer_pow) in 0.034348726 sec
# DEBUG:jax._src.dispatch:Finished XLA compilation of jit(integer_pow) in 0.034348726 sec
# DEBUG:2025-11-21 18:46:51,387:jax._src.dispatch:198: Finished tracing + transforming log1p for pjit in 0.000719309 sec
# DEBUG:jax._src.dispatch:Finished tracing + transforming log1p for pjit in 0.000719309 sec
# DEBUG:2025-11-21 18:46:51,390:jax._src.interpreters.pxla:1861: Compiling jit(log1p) with global shapes and types [ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:jax._src.interpreters.pxla:Compiling jit(log1p) with global shapes and types [ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:2025-11-21 18:46:51,395:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(log1p) in 0.004497766 sec
# DEBUG:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(log1p) in 0.004497766 sec
# DEBUG:2025-11-21 18:46:51,397:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:jax._src.compiler:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-11-21 18:46:51,399:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:jax._src.compiler:get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-11-21 18:46:51,400:jax._src.cache_key:156: get_cache_key hash of serialized computation: 861be8ea31700e2cdbbe91d23eac5770ddb2746e59b935ec375c7561f77a7747
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized computation: 861be8ea31700e2cdbbe91d23eac5770ddb2746e59b935ec375c7561f77a7747
# DEBUG:2025-11-21 18:46:51,401:jax._src.cache_key:162: get_cache_key hash after serializing computation: 861be8ea31700e2cdbbe91d23eac5770ddb2746e59b935ec375c7561f77a7747
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing computation: 861be8ea31700e2cdbbe91d23eac5770ddb2746e59b935ec375c7561f77a7747
# DEBUG:2025-11-21 18:46:51,402:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-11-21 18:46:51,403:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 7ba11ec74192ee7e5ae912b6afac782c10b9ca1ca7c2d04973332bb76cfdb594
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing jax_lib version: 7ba11ec74192ee7e5ae912b6afac782c10b9ca1ca7c2d04973332bb76cfdb594
# DEBUG:2025-11-21 18:46:51,404:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-11-21 18:46:51,405:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 374276625ce1570aa34fa6f721ae415e119f7084d91dc7eb5bd5e990c5bd3437
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing backend version: 374276625ce1570aa34fa6f721ae415e119f7084d91dc7eb5bd5e990c5bd3437
# DEBUG:2025-11-21 18:46:51,406:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,406:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 374276625ce1570aa34fa6f721ae415e119f7084d91dc7eb5bd5e990c5bd3437
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing XLA flags: 374276625ce1570aa34fa6f721ae415e119f7084d91dc7eb5bd5e990c5bd3437
# DEBUG:2025-11-21 18:46:51,408:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: aa380e371b08ff0dcd1b3c71afe5a65897fc18d492ebf60407feb75501a0daca
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compile_options: aa380e371b08ff0dcd1b3c71afe5a65897fc18d492ebf60407feb75501a0daca
# DEBUG:2025-11-21 18:46:51,408:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 6de0c1dcfbe26d34133cf8d726deb8ba656ac75700b0499988f04dd1ca79a15a
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compile_options: 6de0c1dcfbe26d34133cf8d726deb8ba656ac75700b0499988f04dd1ca79a15a
# DEBUG:2025-11-21 18:46:51,409:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:2025-11-21 18:46:51,410:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 48c50626d23e2ad034ea642ce66163e35d545b6e14e7bd3469d63ef92f77fc1f
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing accelerator_config: 48c50626d23e2ad034ea642ce66163e35d545b6e14e7bd3469d63ef92f77fc1f
# DEBUG:2025-11-21 18:46:51,411:jax._src.cache_key:156: get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:2025-11-21 18:46:51,411:jax._src.cache_key:162: get_cache_key hash after serializing compression: 521f68253c671a892a0d3209b5390c825186fe92c0f41655cacafa850d37dc0f
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compression: 521f68253c671a892a0d3209b5390c825186fe92c0f41655cacafa850d37dc0f
# DEBUG:2025-11-21 18:46:51,412:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,413:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 521f68253c671a892a0d3209b5390c825186fe92c0f41655cacafa850d37dc0f
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing custom_hook: 521f68253c671a892a0d3209b5390c825186fe92c0f41655cacafa850d37dc0f
# DEBUG:2025-11-21 18:46:51,414:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:jax._src.compilation_cache:get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-11-21 18:46:51,415:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_log1p' with key 'jit_log1p-521f68253c671a892a0d3209b5390c825186fe92c0f41655cacafa850d37dc0f'
# DEBUG:jax._src.compiler:PERSISTENT COMPILATION CACHE MISS for 'jit_log1p' with key 'jit_log1p-521f68253c671a892a0d3209b5390c825186fe92c0f41655cacafa850d37dc0f'
# DEBUG:2025-11-21 18:46:51,434:jax._src.compiler:831: Not writing persistent cache entry for 'jit_log1p' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:jax._src.compiler:Not writing persistent cache entry for 'jit_log1p' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:2025-11-21 18:46:51,435:jax._src.dispatch:198: Finished XLA compilation of jit(log1p) in 0.034926891 sec
# DEBUG:jax._src.dispatch:Finished XLA compilation of jit(log1p) in 0.034926891 sec
# DEBUG:2025-11-21 18:46:51,447:jax._src.dispatch:198: Finished tracing + transforming copy for pjit in 0.000201702 sec
# DEBUG:jax._src.dispatch:Finished tracing + transforming copy for pjit in 0.000201702 sec
# DEBUG:2025-11-21 18:46:51,449:jax._src.interpreters.pxla:1861: Compiling jit(copy) with global shapes and types [ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:jax._src.interpreters.pxla:Compiling jit(copy) with global shapes and types [ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:2025-11-21 18:46:51,455:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(copy) in 0.004953861 sec
# DEBUG:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(copy) in 0.004953861 sec
# DEBUG:2025-11-21 18:46:51,457:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:jax._src.compiler:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-11-21 18:46:51,459:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:jax._src.compiler:get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-11-21 18:46:51,460:jax._src.cache_key:156: get_cache_key hash of serialized computation: 93874d0adac00145113510b5b4e6cd866fe8fe09cbaabdb022caea56504730c5
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized computation: 93874d0adac00145113510b5b4e6cd866fe8fe09cbaabdb022caea56504730c5
# DEBUG:2025-11-21 18:46:51,461:jax._src.cache_key:162: get_cache_key hash after serializing computation: 93874d0adac00145113510b5b4e6cd866fe8fe09cbaabdb022caea56504730c5
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing computation: 93874d0adac00145113510b5b4e6cd866fe8fe09cbaabdb022caea56504730c5
# DEBUG:2025-11-21 18:46:51,461:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-11-21 18:46:51,462:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 68be5996dfbbaa4381d8c0a73c3f7abcad5171938191e3acef615cbd19a1f5ec
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing jax_lib version: 68be5996dfbbaa4381d8c0a73c3f7abcad5171938191e3acef615cbd19a1f5ec
# DEBUG:2025-11-21 18:46:51,463:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-11-21 18:46:51,463:jax._src.cache_key:162: get_cache_key hash after serializing backend version: 8f3b3222b22628bb1e73a03ab7e0b7d003615189b73dcf50116cc646c726df5b
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing backend version: 8f3b3222b22628bb1e73a03ab7e0b7d003615189b73dcf50116cc646c726df5b
# DEBUG:2025-11-21 18:46:51,464:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,465:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: 8f3b3222b22628bb1e73a03ab7e0b7d003615189b73dcf50116cc646c726df5b
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing XLA flags: 8f3b3222b22628bb1e73a03ab7e0b7d003615189b73dcf50116cc646c726df5b
# DEBUG:2025-11-21 18:46:51,466:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: aa380e371b08ff0dcd1b3c71afe5a65897fc18d492ebf60407feb75501a0daca
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compile_options: aa380e371b08ff0dcd1b3c71afe5a65897fc18d492ebf60407feb75501a0daca
# DEBUG:2025-11-21 18:46:51,466:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 0b833dd3e360d696d3167d8d274b77a017772980f418fa37d777019fad979781
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compile_options: 0b833dd3e360d696d3167d8d274b77a017772980f418fa37d777019fad979781
# DEBUG:2025-11-21 18:46:51,467:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:2025-11-21 18:46:51,468:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: d18b35a77d822e6bddd594bba61be49ac01ff598155ecc1864a6de54b922fe9c
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing accelerator_config: d18b35a77d822e6bddd594bba61be49ac01ff598155ecc1864a6de54b922fe9c
# DEBUG:2025-11-21 18:46:51,469:jax._src.cache_key:156: get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:2025-11-21 18:46:51,469:jax._src.cache_key:162: get_cache_key hash after serializing compression: be4b0920d224c70f633e6c57b8d59a9da40d9b67b38c2f71e243e0faec9fac29
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compression: be4b0920d224c70f633e6c57b8d59a9da40d9b67b38c2f71e243e0faec9fac29
# DEBUG:2025-11-21 18:46:51,470:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,471:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: be4b0920d224c70f633e6c57b8d59a9da40d9b67b38c2f71e243e0faec9fac29
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing custom_hook: be4b0920d224c70f633e6c57b8d59a9da40d9b67b38c2f71e243e0faec9fac29
# DEBUG:2025-11-21 18:46:51,471:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:jax._src.compilation_cache:get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-11-21 18:46:51,472:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_copy' with key 'jit_copy-be4b0920d224c70f633e6c57b8d59a9da40d9b67b38c2f71e243e0faec9fac29'
# DEBUG:jax._src.compiler:PERSISTENT COMPILATION CACHE MISS for 'jit_copy' with key 'jit_copy-be4b0920d224c70f633e6c57b8d59a9da40d9b67b38c2f71e243e0faec9fac29'
# DEBUG:2025-11-21 18:46:51,482:jax._src.compiler:831: Not writing persistent cache entry for 'jit_copy' because it took < 1.00 seconds to compile (0.01s)
# DEBUG:jax._src.compiler:Not writing persistent cache entry for 'jit_copy' because it took < 1.00 seconds to compile (0.01s)
# DEBUG:2025-11-21 18:46:51,483:jax._src.dispatch:198: Finished XLA compilation of jit(copy) in 0.023944139 sec
# DEBUG:jax._src.dispatch:Finished XLA compilation of jit(copy) in 0.023944139 sec
# DEBUG:2025-11-21 18:46:51,486:jax._src.dispatch:198: Finished tracing + transforming true_divide for pjit in 0.000382185 sec
# DEBUG:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.000382185 sec
# DEBUG:2025-11-21 18:46:51,488:jax._src.interpreters.pxla:1861: Compiling jit(true_divide) with global shapes and types [ShapedArray(float32[2]), ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:jax._src.interpreters.pxla:Compiling jit(true_divide) with global shapes and types [ShapedArray(float32[2]), ShapedArray(float32[])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-11-21 18:46:51,494:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(true_divide) in 0.003931284 sec
# DEBUG:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(true_divide) in 0.003931284 sec
# DEBUG:2025-11-21 18:46:51,495:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:jax._src.compiler:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-11-21 18:46:51,497:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:jax._src.compiler:get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-11-21 18:46:51,499:jax._src.cache_key:156: get_cache_key hash of serialized computation: 04334631c856ff96926e50acf96d76b27e7d70dd472b34aa177c5fb474529741
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized computation: 04334631c856ff96926e50acf96d76b27e7d70dd472b34aa177c5fb474529741
# DEBUG:2025-11-21 18:46:51,500:jax._src.cache_key:162: get_cache_key hash after serializing computation: 04334631c856ff96926e50acf96d76b27e7d70dd472b34aa177c5fb474529741
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing computation: 04334631c856ff96926e50acf96d76b27e7d70dd472b34aa177c5fb474529741
# DEBUG:2025-11-21 18:46:51,501:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-11-21 18:46:51,502:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 4f4b5448a0ec93ba389f5cb6125d7fe8ca079d5b739d773698f1e52db0ab6aeb
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing jax_lib version: 4f4b5448a0ec93ba389f5cb6125d7fe8ca079d5b739d773698f1e52db0ab6aeb
# DEBUG:2025-11-21 18:46:51,503:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-11-21 18:46:51,503:jax._src.cache_key:162: get_cache_key hash after serializing backend version: e4bb0fa88a73f7fe79773114f05d9c2dacd4b770ddf34426439625e2e94aea69
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing backend version: e4bb0fa88a73f7fe79773114f05d9c2dacd4b770ddf34426439625e2e94aea69
# DEBUG:2025-11-21 18:46:51,504:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,505:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: e4bb0fa88a73f7fe79773114f05d9c2dacd4b770ddf34426439625e2e94aea69
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing XLA flags: e4bb0fa88a73f7fe79773114f05d9c2dacd4b770ddf34426439625e2e94aea69
# ...
# DEBUG:2025-11-21 18:46:51,608:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:jax._src.compilation_cache:get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-11-21 18:46:51,609:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_square' with key 'jit_square-43cd73d26e32d2a73b6d1d5d42ba52de1ffed1f49a35088b7bcc2b80d2738a4f'
# DEBUG:jax._src.compiler:PERSISTENT COMPILATION CACHE MISS for 'jit_square' with key 'jit_square-43cd73d26e32d2a73b6d1d5d42ba52de1ffed1f49a35088b7bcc2b80d2738a4f'
# DEBUG:2025-11-21 18:46:51,627:jax._src.compiler:831: Not writing persistent cache entry for 'jit_square' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:jax._src.compiler:Not writing persistent cache entry for 'jit_square' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:2025-11-21 18:46:51,629:jax._src.dispatch:198: Finished XLA compilation of jit(square) in 0.038732052 sec
# DEBUG:jax._src.dispatch:Finished XLA compilation of jit(square) in 0.038732052 sec
# DEBUG:2025-11-21 18:46:51,633:jax._src.dispatch:198: Finished tracing + transforming multiply for pjit in 0.000443459 sec
# DEBUG:jax._src.dispatch:Finished tracing + transforming multiply for pjit in 0.000443459 sec
# DEBUG:2025-11-21 18:46:51,635:jax._src.interpreters.pxla:1861: Compiling jit(multiply) with global shapes and types [ShapedArray(float32[], weak_type=True), ShapedArray(float32[2])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:jax._src.interpreters.pxla:Compiling jit(multiply) with global shapes and types [ShapedArray(float32[], weak_type=True), ShapedArray(float32[2])]. Argument mapping: (UnspecifiedValue, UnspecifiedValue).
# DEBUG:2025-11-21 18:46:51,641:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(multiply) in 0.004258394 sec
# DEBUG:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(multiply) in 0.004258394 sec
# DEBUG:2025-11-21 18:46:51,642:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:jax._src.compiler:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-11-21 18:46:51,644:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:jax._src.compiler:get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-11-21 18:46:51,646:jax._src.cache_key:156: get_cache_key hash of serialized computation: 07f034a3458cf2141400652194e41e2f018e018a796c9c390a9dc0f89315198b
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized computation: 07f034a3458cf2141400652194e41e2f018e018a796c9c390a9dc0f89315198b
# DEBUG:2025-11-21 18:46:51,647:jax._src.cache_key:162: get_cache_key hash after serializing computation: 07f034a3458cf2141400652194e41e2f018e018a796c9c390a9dc0f89315198b
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing computation: 07f034a3458cf2141400652194e41e2f018e018a796c9c390a9dc0f89315198b
# DEBUG:2025-11-21 18:46:51,648:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-11-21 18:46:51,649:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 9c6cb8c4aede5cbb010bf370edc07ca260f7fa0b4d1d7aeae3082146a88e819d
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing jax_lib version: 9c6cb8c4aede5cbb010bf370edc07ca260f7fa0b4d1d7aeae3082146a88e819d
# DEBUG:2025-11-21 18:46:51,650:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-11-21 18:46:51,651:jax._src.cache_key:162: get_cache_key hash after serializing backend version: a6c5b284ab16be18f1428792fe25b2627a2e8572f6c169fb765cec87cba419c3
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing backend version: a6c5b284ab16be18f1428792fe25b2627a2e8572f6c169fb765cec87cba419c3
# DEBUG:2025-11-21 18:46:51,652:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,653:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: a6c5b284ab16be18f1428792fe25b2627a2e8572f6c169fb765cec87cba419c3
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing XLA flags: a6c5b284ab16be18f1428792fe25b2627a2e8572f6c169fb765cec87cba419c3
# DEBUG:2025-11-21 18:46:51,654:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: 8d8e388f48e4efc23534e450e33eafda61382f4d9c61c2c29fc11dd20315a2df
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compile_options: 8d8e388f48e4efc23534e450e33eafda61382f4d9c61c2c29fc11dd20315a2df
# DEBUG:2025-11-21 18:46:51,655:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: 57fd556bd2ecba01af20d4571046e96eac2cf2a93c813b27731af0f4f84c5329
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compile_options: 57fd556bd2ecba01af20d4571046e96eac2cf2a93c813b27731af0f4f84c5329
# DEBUG:2025-11-21 18:46:51,656:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:2025-11-21 18:46:51,657:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: 8a5b9f5f6e12ed3b1a3584bdda883aad392004a1a7cad311629e2974a3c39487
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing accelerator_config: 8a5b9f5f6e12ed3b1a3584bdda883aad392004a1a7cad311629e2974a3c39487
# DEBUG:2025-11-21 18:46:51,658:jax._src.cache_key:156: get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:2025-11-21 18:46:51,659:jax._src.cache_key:162: get_cache_key hash after serializing compression: e104a669fb3b446b681fdd8155e1711feb1b25804999b3b2172fdc3ce6ba2c1e
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compression: e104a669fb3b446b681fdd8155e1711feb1b25804999b3b2172fdc3ce6ba2c1e
# DEBUG:2025-11-21 18:46:51,660:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,661:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: e104a669fb3b446b681fdd8155e1711feb1b25804999b3b2172fdc3ce6ba2c1e
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing custom_hook: e104a669fb3b446b681fdd8155e1711feb1b25804999b3b2172fdc3ce6ba2c1e
# DEBUG:2025-11-21 18:46:51,662:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:jax._src.compilation_cache:get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-11-21 18:46:51,664:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit_multiply' with key 'jit_multiply-e104a669fb3b446b681fdd8155e1711feb1b25804999b3b2172fdc3ce6ba2c1e'
# DEBUG:jax._src.compiler:PERSISTENT COMPILATION CACHE MISS for 'jit_multiply' with key 'jit_multiply-e104a669fb3b446b681fdd8155e1711feb1b25804999b3b2172fdc3ce6ba2c1e'
# DEBUG:2025-11-21 18:46:51,684:jax._src.compiler:831: Not writing persistent cache entry for 'jit_multiply' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:jax._src.compiler:Not writing persistent cache entry for 'jit_multiply' because it took < 1.00 seconds to compile (0.02s)
# DEBUG:2025-11-21 18:46:51,687:jax._src.dispatch:198: Finished XLA compilation of jit(multiply) in 0.041317225 sec
# DEBUG:jax._src.dispatch:Finished XLA compilation of jit(multiply) in 0.041317225 sec
# DEBUG:2025-11-21 18:46:51,691:jax._src.dispatch:198: Finished tracing + transforming _reduce_sum for pjit in 0.000966787 sec
# DEBUG:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.000966787 sec
# DEBUG:2025-11-21 18:46:51,693:jax._src.interpreters.pxla:1861: Compiling jit(_reduce_sum) with global shapes and types [ShapedArray(float32[2])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:jax._src.interpreters.pxla:Compiling jit(_reduce_sum) with global shapes and types [ShapedArray(float32[2])]. Argument mapping: (UnspecifiedValue,).
# DEBUG:2025-11-21 18:46:51,702:jax._src.dispatch:198: Finished jaxpr to MLIR module conversion jit(_reduce_sum) in 0.007186651 sec
# DEBUG:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(_reduce_sum) in 0.007186651 sec
# DEBUG:2025-11-21 18:46:51,703:jax._src.compiler:165: get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:jax._src.compiler:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# DEBUG:2025-11-21 18:46:51,705:jax._src.compiler:247: get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:jax._src.compiler:get_compile_options XLA-AutoFDO profile: using XLA-AutoFDO profile version -1
# DEBUG:2025-11-21 18:46:51,706:jax._src.cache_key:156: get_cache_key hash of serialized computation: f1924c0916cbb2a3bcc3223f592265579c645170a6555a2e579c9de1f1798224
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized computation: f1924c0916cbb2a3bcc3223f592265579c645170a6555a2e579c9de1f1798224
# DEBUG:2025-11-21 18:46:51,707:jax._src.cache_key:162: get_cache_key hash after serializing computation: f1924c0916cbb2a3bcc3223f592265579c645170a6555a2e579c9de1f1798224
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing computation: f1924c0916cbb2a3bcc3223f592265579c645170a6555a2e579c9de1f1798224
# DEBUG:2025-11-21 18:46:51,707:jax._src.cache_key:156: get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized jax_lib version: b0cb276cde517779ca43a5f8fe94adcd6b1ca3b4e7da5e97f2ccd9c3b4381df8
# DEBUG:2025-11-21 18:46:51,708:jax._src.cache_key:162: get_cache_key hash after serializing jax_lib version: 1a22719d56764e9f854e41df2e8a4e2509b79afcfd87142183127f7b0513dd50
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing jax_lib version: 1a22719d56764e9f854e41df2e8a4e2509b79afcfd87142183127f7b0513dd50
# DEBUG:2025-11-21 18:46:51,709:jax._src.cache_key:156: get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized backend version: d01711a267aea6695c681e4e75ed43f0e973d36f19b2f3c261d517b8c32285b2
# DEBUG:2025-11-21 18:46:51,710:jax._src.cache_key:162: get_cache_key hash after serializing backend version: e0ab26fb47283e94ba88e5cfa302210905718883a853313d6d8dbdd2eb90156e
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing backend version: e0ab26fb47283e94ba88e5cfa302210905718883a853313d6d8dbdd2eb90156e
# DEBUG:2025-11-21 18:46:51,710:jax._src.cache_key:156: get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized XLA flags: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,711:jax._src.cache_key:162: get_cache_key hash after serializing XLA flags: e0ab26fb47283e94ba88e5cfa302210905718883a853313d6d8dbdd2eb90156e
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing XLA flags: e0ab26fb47283e94ba88e5cfa302210905718883a853313d6d8dbdd2eb90156e
# DEBUG:2025-11-21 18:46:51,712:jax._src.cache_key:156: get_cache_key hash of serialized compile_options: aa380e371b08ff0dcd1b3c71afe5a65897fc18d492ebf60407feb75501a0daca
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compile_options: aa380e371b08ff0dcd1b3c71afe5a65897fc18d492ebf60407feb75501a0daca
# DEBUG:2025-11-21 18:46:51,713:jax._src.cache_key:162: get_cache_key hash after serializing compile_options: e2af49a6306f679cfc902d9216fcd9194406f3666fdefcc58d4ef4b01e7fb555
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compile_options: e2af49a6306f679cfc902d9216fcd9194406f3666fdefcc58d4ef4b01e7fb555
# DEBUG:2025-11-21 18:46:51,714:jax._src.cache_key:156: get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized accelerator_config: a5879db9ea318e022a2a56b8222e0a201a7299b24c86c79dd546a27a954020e7
# DEBUG:2025-11-21 18:46:51,718:jax._src.cache_key:162: get_cache_key hash after serializing accelerator_config: b2e2f498235bb3e9b8f963bf8133d1679e390f1966c98b8a89ce360914b2068b
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing accelerator_config: b2e2f498235bb3e9b8f963bf8133d1679e390f1966c98b8a89ce360914b2068b
# DEBUG:2025-11-21 18:46:51,720:jax._src.cache_key:156: get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized compression: 0ea55c28f8014d8886b6248fe3da5d588f55c0823847a6b4579f1131b051b5e2
# DEBUG:2025-11-21 18:46:51,721:jax._src.cache_key:162: get_cache_key hash after serializing compression: 0ff7ed5ae2bc74b7592b6b5197dbcf8184322ddcdf812cf3272409056357d869
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing compression: 0ff7ed5ae2bc74b7592b6b5197dbcf8184322ddcdf812cf3272409056357d869
# DEBUG:2025-11-21 18:46:51,722:jax._src.cache_key:156: get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:jax._src.cache_key:get_cache_key hash of serialized custom_hook: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG:2025-11-21 18:46:51,723:jax._src.cache_key:162: get_cache_key hash after serializing custom_hook: 0ff7ed5ae2bc74b7592b6b5197dbcf8184322ddcdf812cf3272409056357d869
# DEBUG:jax._src.cache_key:get_cache_key hash after serializing custom_hook: 0ff7ed5ae2bc74b7592b6b5197dbcf8184322ddcdf812cf3272409056357d869
# DEBUG:2025-11-21 18:46:51,724:jax._src.compilation_cache:217: get_executable_and_time: cache is disabled/not initialized
# DEBUG:jax._src.compilation_cache:get_executable_and_time: cache is disabled/not initialized
# DEBUG:2025-11-21 18:46:51,725:jax._src.compiler:111: PERSISTENT COMPILATION CACHE MISS for 'jit__reduce_sum' with key 'jit__reduce_sum-0ff7ed5ae2bc74b7592b6b5197dbcf8184322ddcdf812cf3272409056357d869'
# DEBUG:jax._src.compiler:PERSISTENT COMPILATION CACHE MISS for 'jit__reduce_sum' with key 'jit__reduce_sum-0ff7ed5ae2bc74b7592b6b5197dbcf8184322ddcdf812cf3272409056357d869'
# DEBUG:2025-11-21 18:46:51,753:jax._src.compiler:831: Not writing persistent cache entry for 'jit__reduce_sum' because it took < 1.00 seconds to compile (0.03s)
# DEBUG:jax._src.compiler:Not writing persistent cache entry for 'jit__reduce_sum' because it took < 1.00 seconds to compile (0.03s)
# DEBUG:2025-11-21 18:46:51,755:jax._src.dispatch:198: Finished XLA compilation of jit(_reduce_sum) in 0.049208403 sec
# DEBUG:jax._src.dispatch:Finished XLA compilation of jit(_reduce_sum) in 0.049208403 sec
# After model building - lazy_var is weak: True
# Lazy evaluation with auto_transform still works!
# Model variables: ['y_lazy', 'lazy_var', 'lazy_var_transformed']

# %% [markdown]
# ### 6.3 Both APIs can coexist

# %%
# Use new API for one parameter
eager_param = lsl.Var(1.0, distribution=lsl.Dist(tfd.HalfCauchy, loc=0.0, scale=25.0), name="eager_param", bijector="auto")

# Use old API for another
lazy_param = lsl.Var.new_param(2.0, distribution=lsl.Dist(tfd.HalfCauchy, loc=0.0, scale=25.0), name="lazy_param")
lazy_param.auto_transform = True

print(f"eager_param is weak (eager): {eager_param.weak}")
print(f"lazy_param is weak (before model): {lazy_param.weak}")

# Build model with both
mixed_dist = lsl.Dist(tfd.Normal, loc=eager_param, scale=lazy_param)
y_mixed = lsl.Var.new_obs(jnp.array([1.0]), distribution=mixed_dist, name="y_mixed")
gb_mixed = lsl.GraphBuilder().add(y_mixed)
model_mixed = gb_mixed.build_model()

print(f"\nAfter model building:")
print(f"eager_param is weak: {eager_param.weak}")
print(f"lazy_param is weak: {lazy_param.weak}")
# Out:
# eager_param is weak (eager): True
# lazy_param is weak (before model): False
#
# After model building:
# eager_param is weak: True
# lazy_param is weak: True
